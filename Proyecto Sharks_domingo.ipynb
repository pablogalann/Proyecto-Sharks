# %% [markdown]
# ### 1º) IMPORTAR PANDAS, NUMPY, VISUALIZACION FILAS Y COLUMNAS, BLOQUE DE ERRORES

# %%
import pandas as pd  # importación de pandas 
import numpy as np  # importacion de numpy 

pd.set_option('display.max_columns', None)  # mostrar todas las columnas del df 
pd.set_option('display.max_rows', None)   # mostrar todas las filas del df

import warnings  # importacion de bloqueo de errores
warnings.filterwarnings('ignore')

import pylab as plt    # visualización
import seaborn as sns    # visualización

# %matplotlib inline

# %% [markdown]
# ### 2º) ABRIR EL ARCHIVO. ( r' + RUTA CARPETA UBICACION DE ARCHIVO + \NOMBRE_ARCHIVO.csv ,encoding='latin1' )

# %%
data = pd.read_csv(r'C:\Users\pablo\Proyecto-Sharks\data\attacks.csv',encoding='latin1')

# %% [markdown]
# ### 3º) VISUALIZACION DE INFORMACION GENERAL: .head .info, .shape .columns

# %%
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25          6303.0         NaN         NaN
# 1    2018.06.18          6302.0         NaN         NaN
# 2    2018.06.09          6301.0         NaN         NaN
# 3    2018.06.08          6300.0         NaN         NaN
# 4    2018.06.04          6299.0         NaN         NaN

# %% [markdown]
# VISUALIZACION DE INDICE DE CARPETAS

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# VISUALIZACIÓN DEL TIPO ELEMENTOS EN CADA COLUMNA, TAMAÑO ARCHIVO , BITS

# %%
data.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 22.8 MB

# %% [markdown]
# VISUALIZACION DE LAS COLUMNAS CON VALORES 'OBJETO'

# %%
data.select_dtypes(include='object').head()
# Out:
#   Case Number         Date        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 Unnamed: 22 Unnamed: 23
# 0    2018.06.25         NaN         NaN
# 1    2018.06.18         NaN         NaN
# 2    2018.06.09         NaN         NaN
# 3    2018.06.08         NaN         NaN
# 4    2018.06.04         NaN         NaN

# %% [markdown]
# VISUALIZACIÓN DE COLUMNAS CON VALORES DE TIPO NUMERICO:
# Según hemos podido ver en la .info 'deep' = 'Year' y 'Original Order' son float64

# %%
data.select_dtypes(exclude='object').head()
# Out:
#      Year  original order
# 0  2018.0          6303.0
# 1  2018.0          6302.0
# 2  2018.0          6301.0
# 3  2018.0          6300.0
# 4  2018.0          6299.0

# %% [markdown]
# ### 4º) MODIFICIAR TITULOS DE LAS COLUMNAS:
# Queremos evitar espacios y diferencias entre mayusculas y minusculas.

# %%
data.columns = [c.title().replace(' ','')for c in data.columns]

# %% [markdown]
# Para cada titulo de columna (df.columns) en el dataframe:
#
# - si hay un espacio sustituyelo por 'nada'
# - Convierte la primera letra en mayuscula.
# - Comprobación  = data.columns  ↓ ↓ ↓

# %%
data.columns
# Out:
# Index(['CaseNumber', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal(Y/N)', 'Time',
#        'Species', 'InvestigatorOrSource', 'Pdf', 'HrefFormula', 'Href',
#        'CaseNumber.1', 'CaseNumber.2', 'OriginalOrder', 'Unnamed:22',
#        'Unnamed:23'],
#       dtype='object')

# %% [markdown]
# ### 5º) Localizar valores nulos:
#
# - Creamos una nueva variable donde apareceran las columnas con valores NaN, llamada nan_cols.
# - ¿Que valores del dataFrame son nulos? df.isna()
# - Muestrame las columnas con valores nulos donde en esas columnas dichos valores sean superiores a cero.

# %% [markdown]
# A. Muestrame los valores segun el PORCENTAJE % que representan en la columna

# %%
nan_cols = data.isna().mean()*100 
nan_cols[nan_cols>0]
# Out:
# CaseNumber              66.170353
# Date                    75.500525
# Year                    75.508300
# Type                    75.516075
# Country                 75.694903
# Area                    77.269370
# Location                77.599813
# Activity                77.615364
# Name                    76.316915
# Sex                     77.697003
# Age                     86.506240
# Injury                  75.609377
# Fatal(Y/N)              77.595926
# Time                    88.539439
# Species                 86.533453
# InvestigatorOrSource    75.566614
# Pdf                     75.500525
# HrefFormula             75.504412
# Href                    75.500525
# CaseNumber.1            75.500525
# CaseNumber.2            75.500525
# OriginalOrder           75.473312
# Unnamed:22              99.996112
# Unnamed:23              99.992225
# dtype: float64

# %% [markdown]
# B. Muestame el SUMATORIO de datos nulos en cada columna.

# %%
nan_cols = data.isna().sum() 
nan_cols[nan_cols>0]
# Out:
# CaseNumber              17021
# Date                    19421
# Year                    19423
# Type                    19425
# Country                 19471
# Area                    19876
# Location                19961
# Activity                19965
# Name                    19631
# Sex                     19986
# Age                     22252
# Injury                  19449
# Fatal(Y/N)              19960
# Time                    22775
# Species                 22259
# InvestigatorOrSource    19438
# Pdf                     19421
# HrefFormula             19422
# Href                    19421
# CaseNumber.1            19421
# CaseNumber.2            19421
# OriginalOrder           19414
# Unnamed:22              25722
# Unnamed:23              25721
# dtype: int64

# %% [markdown]
# ### 6º) Borrado de columnas con un porcentaje de nulos muy elevado/ con un gran numero de nulos
#
#                 data.drop( columns = nombre_columna[nombre_columna>condición].index , inplace = True)
#
# EJEMPLOS
#
# - Borrame las columnas(columns = ) de dentro de las columnas con nulos(nan_cols) cuyos % valores nulos es superior a 90%(>90)
#
# data.drop(columns=nan_cols[nan_cols>90].index, inplace = True)
#
# - Borrame las columnas(columns = ) de dentro de las columnas con nulos(nan_cols) cuyos valores son superiores 10000ud
#
# data.drop(columns=nan_cols[nan_cols>1e4].index, inplace = True)

# %%
nan_cols = data.isna().mean()*100
nan_cols[nan_cols>0]

data.drop(columns=nan_cols[nan_cols>90].index, inplace = True)

# %% [markdown]
# Comprabación de que se han borrado las columnas

# %%
data.shape
# Out:
# (25723, 22)

# %% [markdown]
# ### 7º) Localizacion gráfica de datos nulos según los datos obtenidos anteriormente

# %%
plt.figure(figsize=(10, 6)) 

sns.heatmap(data.isna(), 
           yticklabels=False,
           cmap='viridis',
           cbar=False)

plt.show()

# %% [markdown]
# ### 8º) BORRADO DE FILAS CON ALTO CONTENIDO EN NULOS:
#
# - ES MÁS RAPIDO Y PREFERIBLE UTILIZAR EL MÉTODO DE BORRAR DUPLICADOS:
#
# data.drop_duplicates().shape==data.shape
#
# data.drop_duplicates(inplace=True)
#
# - AQUI METODO DE BORRADO POR FILAS ↓ ↓ ↓

# %% [markdown]
#                 Nombredataframe.dropna(subset=nombredataframe.columns, inplace = True, how= 'all')
#
#
# Para cada FILA en una grupo de columnas(data.columns, también puede ser una lista de columnas) eliminame aquellas cuyo valor se repite en cada una de las columnas seleccionas(data.columns) IMPORTANTE how = 'all'
#
# Elimina las filas inferiores, ya que en esas filas los valores en las columnas seleccionadas(data.columns) son todos NAN y se repiten en todas y cada una de las casillas de esa fila (how = 'all')

# %%
data.dropna(subset= data.columns,inplace= True, how= 'all')

# %%
data.shape
# Out:
# (8703, 22)

# %% [markdown]
# COMPROBAMOS GRAFICAMENTE OTRA VEZ, COMO HAN QUEDADO LOS NULOS DESPUES DE BORRAR EL PRIMER PAQUETE DE FILAS.

# %%
plt.figure(figsize=(10, 6)) 

sns.heatmap(data.isna(), 
           yticklabels=False,
           cmap='viridis',
           cbar=False)

plt.show()

# %% [markdown]
# Siguen apareciendo filas donde los valores nulos se repiten a lo largo de ella en todas las columnas a excepciòn de una:
#
# - Repetimos la linea de código anterior pero eliminamos la columna donde no se repite en el subset. Por que a pesar de que en el estas filas haya un valor real, las 22 siguientes solo hay nulos, por tanto prescindimos de ellas.

# %%
data.dropna(subset= ['Date', 'Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal(Y/N)', 'Time',
       'Species', 'InvestigatorOrSource', 'Pdf', 'HrefFormula', 'Href',
       'CaseNumber.1', 'CaseNumber.2', 'OriginalOrder'],inplace= True, how= 'all')

# %%
data.shape
# Out:
# (6309, 22)

# %% [markdown]
# ### 9º) MODIFICACIÓN DE VALORES NULOS
#
# Lineas de codigo basicas de busqueda:
#
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?
#
# nan_cols = data.isna().sum()
# nan_cols[nan_cols>0]
#
#
# 2º ¿En que fila estan estos nulos? Contextualizamos con la informacion en el resto de columnas
#
# data[data['nombrecolumna'].isna()]
#
# 3º) SUSTITUIR NULOS por 'Unknown' ceros .... Para poder pasarle la lista de valores a la funcion, nan no interan
#
# data1.nombrecolumna.fillna('Unknown',inplace = True)
# data1.nombrecolumna.fillna(0,inplace = True)
#
#
# 4º ¿ QUE VALORES/OBJETOS HAY en esa columna? Buscamos valores nan y/o inconsistente
#
# data.nombrecolumna.unique()
#
#
# 5º ¿ CUANTOS valores/objetos/elementos hay en esa columna? Buscamos la CANTIDAD de valores inconsistentes
#
# data1.Age.value_counts()

# %%
data1 = data #Guardamos data como version del dataframe original antes de modificar datos nulos.

# %% [markdown]
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# CaseNumber                 1
# Date                       7
# Year                       9
# Type                      11
# Country                   57
# Area                     462
# Location                 547
# Activity                 551
# Name                     217
# Sex                      572
# Age                     2838
# Injury                    35
# Fatal(Y/N)               546
# Time                    3361
# Species                 2845
# InvestigatorOrSource      24
# Pdf                        7
# HrefFormula                8
# Href                       7
# CaseNumber.1               7
# CaseNumber.2               7
# dtype: int64

# %% [markdown]
# ## CaseNumber

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# CaseNumber                 1
# Date                       7
# Year                       9
# Type                      11
# Country                   57
# Area                     462
# Location                 547
# Activity                 551
# Name                     217
# Sex                      572
# Age                     2838
# Injury                    35
# Fatal(Y/N)               546
# Time                    3361
# Species                 2845
# InvestigatorOrSource      24
# Pdf                        7
# HrefFormula                8
# Href                       7
# CaseNumber.1               7
# CaseNumber.2               7
# dtype: int64

# %%
data1[data1['CaseNumber'].isna()]
# Out:
#      CaseNumber                  Date    Year      Type Country     Area  \
# 5488        NaN  Reported 06-Sep-1905  1905.0  Provoked     USA  Florida
#
#                           Location Activity         Name Sex  Age  \
# 5488  Fort Pierce, St Lucie County  Fishing  David Curry   M  NaN
#
#                                                  Injury Fatal(Y/N) Time  \
# 5488  Lacerations to leg from hooked shark PROVOKED ...          N  NaN
#
#      Species            InvestigatorOrSource                     Pdf  \
# 5488     NaN  Muncie Evening Press, 8/6/1913  1905.09.06.R-Curry.pdf
#
#                                             HrefFormula  \
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href  CaseNumber.1  \
# 5488  http://sharkattackfile.net/spreadsheets/pdf_di...  1905.09.06.R
#
#       CaseNumber.2  OriginalOrder
# 5488  1905.09.06.R          815.0

# %% [markdown]
# TENEMOS UN NULO EN LA COLUMNA CaseNumber LOCALIZADO EN LA FILA 5488

# %%
data1['CaseNumber'].ffill(inplace=True) # Sustituir con datatime siguiendo el orden cronologico

# %% [markdown]
# Al ser una columna de fecha, comprobamos que cumple una orden cronologico y al aplicar esa linea de comando sustituye el valor de nulo por una fecha correlativa.
#
# Comprobamos que en la columna Case Number ya no existen valores nulos.
#
# data1[data1['CaseNumber'].isna()] >>> Aparecera una dataframe sin filas
#
# nan_cols = data.isna().sum() >>>> En el listado de columnas con nulos, ya no aparecera la columna CaseNumber
# nan_cols[nan_cols>0]

# %%
data1[data1['CaseNumber'].isna()]
# Out:
# Empty DataFrame
# Columns: [CaseNumber, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal(Y/N), Time, Species, InvestigatorOrSource, Pdf, HrefFormula, Href, CaseNumber.1, CaseNumber.2, OriginalOrder]
# Index: []

# %% [markdown]
# ### Date
#
# Comprobamos que en la columna Date hay 7 valores nulos

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Date                       7
# Year                       9
# Type                      11
# Country                   57
# Area                     462
# Location                 547
# Activity                 551
# Name                     217
# Sex                      572
# Age                     2838
# Injury                    35
# Fatal(Y/N)               546
# Time                    3361
# Species                 2845
# InvestigatorOrSource      24
# Pdf                        7
# HrefFormula                8
# Href                       7
# CaseNumber.1               7
# CaseNumber.2               7
# dtype: int64

# %% [markdown]
# ¿EN QUE FILAS ESTAN LOS VALORES NULOS DE LA COLUMNA DATE?
#
# En la filas 6302/08

# %%
data1[data1.Date.isna()]
# Out:
#      CaseNumber Date  Year Type Country Area Location Activity Name  Sex  Age  \
# 6302          0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  NaN
# 6303          0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  NaN
# 6304          0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  NaN
# 6305          0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  NaN
# 6306          0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  NaN
# 6307          0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  NaN
# 6308          0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN  NaN
#
#      Injury Fatal(Y/N) Time Species InvestigatorOrSource  Pdf HrefFormula  \
# 6302    NaN        NaN  NaN     NaN                  NaN  NaN         NaN
# 6303    NaN        NaN  NaN     NaN                  NaN  NaN         NaN
# 6304    NaN        NaN  NaN     NaN                  NaN  NaN         NaN
# 6305    NaN        NaN  NaN     NaN                  NaN  NaN         NaN
# 6306    NaN        NaN  NaN     NaN                  NaN  NaN         NaN
# 6307    NaN        NaN  NaN     NaN                  NaN  NaN         NaN
# 6308    NaN        NaN  NaN     NaN                  NaN  NaN         NaN
#
#      Href CaseNumber.1 CaseNumber.2  OriginalOrder
# 6302  NaN          NaN          NaN         6304.0
# 6303  NaN          NaN          NaN         6305.0
# 6304  NaN          NaN          NaN         6306.0
# 6305  NaN          NaN          NaN         6307.0
# 6306  NaN          NaN          NaN         6308.0
# 6307  NaN          NaN          NaN         6309.0
# 6308  NaN          NaN          NaN         6310.0

# %% [markdown]
# Al tener todas sus valores menos uno todos nulos las borramos.
#
# nombredf.drop(nombredforiginal.index[final_inicial : final_final+1], inplace = True]

# %%
data1.drop(data.index[6302::], inplace = True)

# %%
data1.tail()
# Out:
#      CaseNumber         Date  Year        Type             Country  \
# 6297    ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298    ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299    ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300    ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301    ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  \
# 6297                   male   M  NaN
# 6298                  Ahmun   M  NaN
# 6299  Coast Guard personnel   M  NaN
# 6300        Jules Patterson   M  NaN
# 6301                   male   M   15
#
#                                                  Injury Fatal(Y/N) Time  \
# 6297                                              FATAL          Y  NaN
# 6298                                              FATAL          Y  NaN
# 6299                                              FATAL          Y  NaN
# 6300                                              FATAL          Y  NaN
# 6301  FATAL. "Shark bit him in half, carrying away t...          Y  NaN
#
#      Species                   InvestigatorOrSource  \
# 6297     NaN       H. Taunton; N. Bartlett,  p. 234
# 6298     NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299     NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300     NaN                    The Sun, 10/20/1938
# 6301     NaN                             S.W. Baker
#
#                                  Pdf  \
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                             HrefFormula  \
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href CaseNumber.1  \
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...      ND.0001
#
#      CaseNumber.2  OriginalOrder
# 6297      ND.0005            6.0
# 6298      ND.0004            5.0
# 6299      ND.0003            4.0
# 6300      ND.0002            3.0
# 6301      ND.0001            2.0

# %%
data1.shape
# Out:
# (6302, 22)

# %% [markdown]
# ### YEAR
#
# Comprobamos que en la columna Year hay 2 valores nulos

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Year                       2
# Type                       4
# Country                   50
# Area                     455
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Age                     2831
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# Species                 2838
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %% [markdown]
# ¿EN QUE FILAS ESTAN LOS VALORES NULOS DE LA COLUMNA DATE?

# %%
data1[data1.Year.isna()]
# Out:
#         CaseNumber                  Date  Year        Type    Country  \
# 187   2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA
# 6079  1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex  Age  \
# 187   Queensland         NaN  Spearfishing  Kerry Daniel   M   35
# 6079  Cumberland  Whitehaven      Swimming         a boy   M  NaN
#
#                                       Injury Fatal(Y/N) Time     Species  \
# 187   No attack, shark made a threat display        NaN  NaN  Bull shark
# 6079                                   FATAL          Y  NaN         NaN
#
#         InvestigatorOrSource                           Pdf  \
# 187   Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf
# 6079          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                             HrefFormula  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6079  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href  CaseNumber.1  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.08.R
# 6079  http://sharkattackfile.net/spreadsheets/pdf_di...  1836.08.19.R
#
#       CaseNumber.2  OriginalOrder
# 187   2017.01.08.R         6116.0
# 6079  1836.08.19.R          224.0

# %% [markdown]
# Al ser unicamente 2 valores nulos lo modificamos manualmente, mediante el comando data.loc:
#
#                     nombredf.loc[fila,'nombrecolumna'] = Nuevo valor de la casilla

# %%
data1.loc[187,'Year'] = 2017  #Cambiamos el valor directamente , conociendo dicho valor accedemos a la fila, columna para sustituirlo manualmente
data1.loc[6079,'Year'] = 1836

# %% [markdown]
# ### COUNTRY
#
# Comprobamos que en la columna 'COUNTRY' hay 50 valores nulos

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Type                       4
# Country                   50
# Area                     455
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Age                     2831
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# Species                 2838
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %% [markdown]
# ¿EN QUE FILAS ESTAN LOS VALORES NULOS DE LA COLUMNA COUNTRY

# %%
data1[data1.Country.isna()]
# Out:
#           CaseNumber                  Date    Year          Type Country  \
# 62      2017.11.13.R  Reported 13-Nov-2017  2017.0    Unprovoked     NaN
# 525       2014.08.00              Aug-2014  2014.0       Invalid     NaN
# 2956    1983.00.00.d              Ca. 1983  1983.0    Unprovoked     NaN
# 3378      1970.11.00              Nov-1970  1970.0    Unprovoked     NaN
# 3387      1970.08.02           02-Aug-1970  1970.0       Invalid     NaN
# 3388      1970.07.05            5-Jul-1970  1970.0    Unprovoked     NaN
# 3395    1970.04.00.b              Apr-1970  1970.0      Provoked     NaN
# 3399      1970.02.05            5-Feb-1970  1970.0    Unprovoked     NaN
# 3425      1969.08.00              Aug-1969  1969.0    Unprovoked     NaN
# 3605      1965.10.21           21-Oct-1965  1965.0    Unprovoked     NaN
# 3661      1964.09.27           27-Sep-1964  1964.0       Invalid     NaN
# 4018      1960.01.26           26-Jan-1960  1960.0  Sea Disaster     NaN
# 3388                                            NaN
# 3395                                            NaN
# 3399                                            NaN
# 3425                                            NaN
# 3605                                            NaN
# 3661                                            NaN
# 4018              Between Timor & Darwin, Australia
# 4231             Near the Andaman & Nicobar Islands
# 4266                   Between Comores & Madagascar
# 4498                                  Caribbean Sea
# 4639                                            NaN
# 4700                       Off South American coast
# 4712  300 miles east of St. Thomas (Virgin Islands)
# 4726                                            NaN
# 4729                                            NaN
# 4911                                            NaN
# 5020                    French Southern Territories
# 5060                                            NaN
# 5425                                            NaN
# 5586                                            NaN
# 5587                                            NaN
# 5612                              Mediterranean Sea
# 5636                                            NaN
# 5742                             Gulf of California
# 5770                                            NaN
# 5808                                  Western Banks
# 5810                                            NaN
# 5839                                            NaN
# 5885                                            NaN
# 5920                                            NaN
# 5996                                            NaN
# 6001                                            NaN
# 6092                                            NaN
# 6119                                            NaN
# 6131                                            NaN
# 6133                                            NaN
# 6137                                      St Helena
# 6155                                            NaN
# 6165                                            NaN
# 6171                                            NaN
# 6175                                     Ionian Sea
# 6177                                     Ionian Sea
# 6199                                            NaN
# 6206                                            NaN
# 6259                                            NaN
#
#                                        Location  \
# 62                                          NaN
# 525                                         NaN
# 2956                                        NaN
# 3378                                        NaN
# 3387                  Between St. Kitts & Nevis
# 3388                                        NaN
# 3395                                        NaN
# 3399                                        NaN
# 3425                                        NaN
# 3605                             Florida Strait
# 3661                                        NaN
# 4018                                        NaN
# 4231                                        NaN
# 4266                                Geyser Bank
# 4498                Between  Cuba  & Costa Rica
# 4639                225 miles east of Hong Kong
# 4700                                        NaN
# 4712                                        NaN
# 4726                                        NaN
# 4729                                        NaN
# 4911                                        NaN
# 5020                             Île Saint-Paul
# 5060                                        NaN
# 5425                           Near the equator
# 5586                                        NaN
# 5587                                        NaN
# 5612                                        NaN
# 5636                                        NaN
# 5742                                        NaN
# 5770                                        NaN
# 5808                                        NaN
# 5810                                 Santa Cruz
# 5839                                        NaN
# 5885                                        NaN
# 5920                                        NaN
# 5996                                        NaN
# 6001                                        NaN
# 6092                                        NaN
# 6119                                        NaN
# 6131                                        NaN
# 6133                                        NaN
# 6137                              Landing Place
# 6155                               Carlisle Bay
# 6165                                        NaN
# 6171                                        NaN
# 6175                                        NaN
# 6177                                        NaN
# 6199                                        NaN
# 6206  In a river feeding into the Bay of Bengal
# 6259                                        NaN
#
#                                                Activity  \
# 62                                              Surfing
# 525                                        Sea disaster
# 2956                                           Swimming
# 3378                                                NaN
# 3387        Sea Disaster Sinking of ferryboat Christina
# 3388                                                NaN
# 3395                                         Freediving
# 3399                                             Wading
# 3425                                                NaN
# 3605                           The boat Caribou II sank
# 3661                                       Spearfishing
# 4018  Portuguese Airliner with 9 people aboard went ...
# 4231                              Climbing back on ship
# 4266                                          Shipwreck
# 4498     Sea Disaster, sinking of the motorship Wingate
# 4639  Japanese POW ship Arisan Maru with 1800 Americ...
# 4700  Dutch merchant ship Zaandam torpedoed  by the ...
# 4712  On life raft tethered to lifeboat. A seaman pu...
# 4726  Jumped overboard from torpedoed Panamanian fre...
# 4729  Days before the surrender of Singapore, the 3 ...
# 4911                                             Diving
# 5020                             Fishing, boat capsized
# 5060                                                NaN
# 5425                                  Jumped overboard
# 5586                                             Diving
# 5587                                             Diving
# 5612                                           Swimming
# 5636                                             Diving
# 5742              Sea disaster, wreck of the sloop Sara
# 5770                                           Swimming
# 5808  Floating, holding onto an oar after dory capsized
# 5810                                            Bathing
# 5839       Jumped overboard after murdering 2 shipmates
# 5885                              Salvaging a shipwreck
# 5920                                     Fell overboard
# 5996                                           Swimming
# 6001                                            Bathing
# 6092                                                NaN
# 6119                                     Fell overboard
# 6131                    Standing on landed shark's tail
# 6133                                  Dropped overboard
# 6137                                           Swimming
# 6155                                           Swimming
# 6165                                                NaN
# 6171                                           Swimming
# 6175                                      Sponge diving
# 6177                              Ascending from a dive
# 6199                                                NaN
# 6206                                     Netting shrimp
# 6259         A group of survivors on a raft for 17-days
#
#                                                    Name  Sex  Age  \
# 62                                        Timur Yunusov    M   24
# 525                                      Cuban refugees    M  NaN
# 2956                 Padma Shri Taranath Narayan Shenoy    M  NaN
# 3378                                      Heinz Plotsky    M  NaN
# 3387                                                NaN  NaN  NaN
# 3388                                               male    M  NaN
# 3395                                      Lionel Jarvis    M  NaN
# 3399                                  Sally Anne Irvine    F    8
# 3425                                      Rodney Hughes    M   25
# 3605                                  Mario Castellanos    M   39
# 3661                                  Giancarlo Griffon    M   24
# 4018                                                NaN  NaN  NaN
# 4231                                               male    M  NaN
# 4266   Captain Eric Hunt, the cook & a French passenger    M  NaN
# 4498                Albert Battles, James Dean & 4 crew    M  NaN
# 4639                                                NaN    M  NaN
# 4700                                                NaN    M  NaN
# 4712                                               male    M  NaN
# 4726                                               male    M  NaN
# 4729  Bombardier J. Hall, Private Green of the Sherw...    M  NaN
# 4911                                  Pearl Purdy Scott    F  NaN
# 5020                                          Quillezic    M  NaN
# 5060                                      Thomas Duggan    M   20
# 5425                                      Thomas Butler    M   36
# 5586                                           Halletts    M  NaN
# 5587                                               male    M  NaN
# 5612                                               male    M  NaN
# 5636                                              Marsh    M  NaN
# 5742                                            2 males    M  NaN
# 5770                                            2 males    M  NaN
# 5808                                    George Sedgwick    M   20
# 5810                                      Father Hudson    M  NaN
# 5839                                        Sherrington    M  NaN
# 5885                                               male    M  NaN
# 5920                                Christian Frederick    M  NaN
# 5996                                 Cornelius Conhlren    M   22
# 6001       a young boy, one of the crew of the Post Boy    M  NaN
# 6092                                               Jose    M  NaN
# 6119                                        John Walker    M  NaN
# 6131                                   Stephen Pettigew    N  NaN
# 6133                                              child  NaN  NaN
# 6137                             Private Isaac Hicksled    M  NaN
# 6155                                 2 impressed seamen    M  NaN
# 6165                                            sailors    M  NaN
# 6171                                               male    M  NaN
# 6175                                              males    M  NaN
# 6177                            Tharsys, a sponge diver    M  NaN
# 6199                                     Phillip Peters    M  NaN
# 6206                                     Sametra Mestri    F  NaN
# 6259                                                 C.  NaN  NaN
#
#                                                  Injury Fatal(Y/N)  \
# 62                              Puncture wounds to feet          N
# 525      Shark involvement prior to death not confirmed        NaN
# 2956                                    Left leg bitten          N
# 3378                                 Extensive injuries          N
# 3387  Sharks scavenged on bodies, but no record of t...        NaN
# 3388                              Finger or toe severed          N
# 3395  Arm abraded & lacerated. Recorded as PROVOKED ...          N
# 3399                           Lacerations to lower leg          N
# 3425                                       Am lacerated          N
# 3605                                           Survived          N
# 3661  Disappeared, probable drowning but sharks in a...        NaN
# 4018  As searchers approached wreckage, sharks circl...          N
# 4231                                              FATAL          Y
# 4266                                              FATAL          Y
# 4498                    Fatal or drowning or scavenging          Y
# 4639  Most of the men drowned & some were taken by s...          Y
# 4700                                              FATAL          Y
# 4712                                  Forearm lacerated          N
# 4726                                              FATAL          Y
# 4729  No injury to occupants. Sharks continually fol...          N
# 4911                             Laceration to left leg          N
# 5020                                              FATAL          Y
# 5060                                              FATAL          Y
# 5425                                              FATAL        NaN
# 5586  Lacerations to hand from shark trapped inside ...          N
# 5587                             Lacerations to fingers          N
# 5612                                              FATAL          Y
# 5636                                 Right hand severed          N
# 5742                                              FATAL          Y
# 5770                                              FATAL          Y
# 5808                                              FATAL          Y
# 5810                                           Survived          N
# 5839                                              FATAL          Y
# 5885                                        Heel bitten          N
# 5920                                              FATAL        NaN
# 5996                                              FATAL          Y
# 6001                                              FATAL          Y
# 6092                                              FATAL          Y
# 6119                                              FATAL          Y
# 6131                           FATAL, PROVOKED INCIDENT          Y
# 6133                                              FATAL          Y
# 6137                                              FATAL          Y
# 6155                                              FATAL          Y
# 6165                                                NaN    UNKNOWN
# 6171                                                NaN    UNKNOWN
# 6175                                              FATAL          Y
# 6177                      FATAL, shark/s bit him in two          Y
# 6199        Bitten by captive sharks PROVOKED INCIDENTS          N
# 6206                                       Hand severed          N
# 6259  FATAL, shark leapt into raft and bit the man w...          Y
#
#                 Time                                            Species  \
# 62               NaN                                                NaN
# 525              NaN                    Shark involvement not confirmed
# 2956             NaN                                                NaN
# 3378             NaN                                                NaN
# 3387       Afternoon  Shark involvement prior to death was not confi...
# 3388           Night                                         Mako shark
# 3395             NaN                                   Wobbegong shark
# 3399             NaN                                       Carpet shark
# 3425             NaN                                                NaN
# 3605             NaN                                                NaN
# 3661           11h00  Shark involvement prior to death was not confi...
# 4018             NaN                                                NaN
# 4231            P.M.                                         Blue shark
# 4266             NaN                                                NaN
# 4498             NaN                    Shark involvement not confirmed
# 4639          >17h30                                                NaN
# 4700             NaN                                                NaN
# 4712             NaN                                                NaN
# 4726             NaN                                                NaN
# 4729             NaN                                                NaN
# 4911             NaN                                                NaN
# 5020             NaN                                                NaN
# 5060             NaN                                                NaN
# 5425             NaN                                       Questionable
# 5586             NaN                                                NaN
# 5587             NaN                                                NaN
# 5612             NaN                                                NaN
# 5636             NaN                                                NaN
# 5742             NaN                                                NaN
# 5770             NaN                                                NaN
# 5808             NaN                                                NaN
# 5810             NaN                                                NaN
# 5839             NaN                                                NaN
# 5885             NaN                                                NaN
# 5920             NaN       Shark involvement prior to death unconfirmed
# 5996             NaN                                                NaN
# 6001             NaN                                                NaN
# 6092           Night                                                NaN
# 6119             NaN                                                NaN
# 5808    1881.08.16.R          495.0
# 5810      1881.06.25          493.0
# 5839      1878.10.13          464.0
# 5885  1874.06.15.a.R          418.0
# 5920      1869.04.10          383.0
# 5996    1856.11.20.R          307.0
# 6001      1855.07.28          302.0
# 6092    1830.04.22.R          211.0
# 6119      1811.03.01          184.0
# 6131    1801.12.18.R          172.0
# 6133    1797.05.28.R          170.0
# 6137      1787.07.05          166.0
# 6155      1742.12.17          148.0
# 6165    1638.00.00.R          138.0
# 6171      1555.00.00          132.0
# 6175      0077.00.00          128.0
# 6177       0000.0214          126.0
# 6199         ND-0124          104.0
# 6206         ND-0114           97.0
# 6259         ND.0044           44.0

# %% [markdown]
# NO SABEMOS REALMENTE EL PAIS DONDE SUCEDIÓ EL ATAQUE VAMOS, LO SUSTITUIMOS POR 'UNKNOWN':
#
#     nombredf.nombrecolumna.fillna('palabrasustituyente',inplace = True)

# %%
data1.Country.fillna('Unknown',inplace = True)

# %% [markdown]
# ### Type
#
# Comprobamos que en la columna 'type' hay 4 valores nulos

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Type                       4
# Area                     455
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Age                     2831
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# Species                 2838
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %% [markdown]
# ¿EN QUE FILAS ESTAN LOS VALORES NULOS DE LA COLUMNA TYPE?

# %%
data1[data1.Type.isna()]
# Out:
#         CaseNumber                  Date    Year Type    Country  \
# 85    2017.09.15.a           15-Sep-2017  2017.0  NaN      SAMOA
# 382     2015.07.27           27-Jul-2015  2015.0  NaN  AUSTRALIA
# 4867  1936.09.11.R  Reported 11-Sep-1936  1936.0  NaN    VIETNAM
# 5705  1890.03.03.R  Reported 03-Mar-1890  1890.0  NaN     CEYLON
#
#                Area          Location           Activity           Name Sex  \
# 85     Upolu Island         Nofoalii            Fishing           male   M
# 382        Victoria  Tyrendarra Beach            Surfing           male   M
# 4867            NaN            Saigon  Wreck of a sampam         8 crew   M
# 5705            NaN               NaN             Diving  a pearl diver   M
#
#       Age                      Injury Fatal(Y/N)   Time Species  \
# 85    NaN  Injuries to hands and legs          N  Night     NaN
# 382    40              Injury to hand        NaN    NaN     NaN
# 4867  NaN                       FATAL          Y    NaN     NaN
# 5705  NaN                       FATAL          Y    NaN     NaN
#
#                   InvestigatorOrSource                      Pdf  \
# 85           Samoa Observer, 9/16/2017   2017.09.15.a-Samoa.pdf
# 382                                NaN  2015.07.27-Victoria.pdf
# 4867  Lansing State Journal, 9/11/1936    1936.09.11-Saigon.pdf
# 5705            The Guardian, 3/3/1890  1890.03.03.R-Ceylon.pdf
#
#                                             HrefFormula  \
# 85    http://sharkattackfile.net/spreadsheets/pdf_di...
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4867  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5705  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href  CaseNumber.1  \
# 85    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.15.a
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.07.27
# 4867  http://sharkattackfile.net/spreadsheets/pdf_di...  1936.09.11.R
# 5705  http://sharkattackfile.net/spreadsheets/pdf_di...  1890.03.03.R
#
#       CaseNumber.2  OriginalOrder
# 85    2017.09.15.a         6218.0
# 382     2015.07.27         5921.0
# 4867  1936.09.11.R         1436.0
# 5705  1890.03.03.R          598.0

# %% [markdown]
# NO CONOCEMOS REALMENTE EL DATO, LO SUSTITUIMOS POR 'UNKNOWN':
#
#     nombredf.nombrecolumna.fillna('palabrasustituyente',inplace = True)

# %%
data1.Type.fillna('Unknown',inplace = True)

# %%
data1.Type.unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', 'Unknown', 'Boat', 'Boatomg'], dtype=object)

# %% [markdown]
# ### Area
#
# Comprobamos que en la columna 'Area' hay 455 valores nulos

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Area                     455
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Age                     2831
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# Species                 2838
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %% [markdown]
# ¿EN QUE FILAS ESTAN LOS VALORES NULOS DE LA COLUMNA TYPE?

# %%
data1[data1.Area.isna()].head()
# Out:
#       CaseNumber                  Date    Year          Type        Country  \
# 32    2018.04.09           09-Apr-2018  2018.0    Unprovoked  NEW CALEDONIA
# 33    2018.04.05           05-Apr-2018  2018.0    Unprovoked        BAHAMAS
# 48    2018.01.21           21-Jan-2018  2018.0    Unprovoked  NEW CALEDONIA
# 56    2017.12.09           09-Dec-2017  2017.0    Unprovoked        BAHAMAS
# 59  2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster          LIBYA
#
#    Area               Location          Activity                 Name  Sex  \
# 32  NaN  Magenta Beach, Noumea       Windsurfing                  NaN  NaN
# 33  NaN                 Bimini          Swimming      Shane McConnell    M
# 48  NaN               Nouville      Spearfishing                 male    M
# 56  NaN                    NaN        Snorkeling  Sarah Illig-Carroll    F
# 59  NaN         Gars Garabulli  2 boats capsized          31 migrants  NaN
#
#     Age                                             Injury Fatal(Y/N)   Time  \
# 32  NaN                         No injury, shark bit board          N  17h00
# 33   12  2 puncture wounds to left foot, abrasion to ri...          N  18h00
# 48  40s                        Injuries to abdomen and arm          N  15h30
# 56   25                                Minor injury to arm          N    NaN
# 59  NaN                                              FATAL          Y    NaN
#
#                                               Species  \
# 32                                          2 m shark
# 33                                         Bull shark
# 48                                   Bull shark, 3 m
# 56                                    Nurse shark. 5'
# 59  Some drowned but other may have been killed by...
#
#                       InvestigatorOrSource                          Pdf  \
# 32  Les Nouvelles Caledoniennes, 4/10/2018       2018.04.09-Magenta.pdf
# 33         K. McMurray, TrackingSharks.com     2018.04.05-McConnell.pdf
# 48                      TrackingSharks.com  2018.01.21-NewCaledonia.pdf
# 56                  Daily Star, 12/11/2017       2017.12.09-Carroll.pdf
# 59                   TG Com 24, 11/25/2017       2017.11.25.R-Libya.pdf
#
#                                           HrefFormula  \
# 32  http://sharkattackfile.net/spreadsheets/pdf_di...
# 33  http://sharkattackfile.net/spreadsheets/pdf_di...
# 48  http://sharkattackfile.net/spreadsheets/pdf_di...
# 56  http://sharkattackfile.net/spreadsheets/pdf_di...
# 59  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                  Href  CaseNumber.1  \
# 32  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.09
# 33  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.05
# 48  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.01.21
# 56  http://sharkattackfile.net/spreadsheets/pdf_di...    2017.12.09
# 59  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.11.25.R
#
#     CaseNumber.2  OriginalOrder
# 32    2018.04.09         6271.0
# 33    2018.04.05         6270.0
# 48    2018.01.21         6255.0
# 56    2017.12.09         6247.0
# 59  2017.11.25.R         6244.0

# %% [markdown]
# NO CONOCEMOS REALMENTE EL DATO, LO SUSTITUIMOS POR 'UNKNOWN':
#
#     nombredf.nombrecolumna.fillna('palabrasustituyente',inplace = True)

# %%
data1.Area.fillna('Unknown',inplace = True)

# %% [markdown]
# ### Age
#
# Comprobamos que en la columna 'Age' hay 2831 valores nulos

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Age                     2831
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# Species                 2838
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %%
data1[data1['Age'].isna()].head()
# Out:
#       CaseNumber         Date    Year          Type       Country  \
# 3     2018.06.08  08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b  03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 15    2018.05.12  12-May-2018  2018.0    Unprovoked  SOUTH AFRICA
# 16    2018.05.09  09-May-2018  2018.0  Questionable     AUSTRALIA
#
#                      Area                   Location      Activity  \
# 3         New South Wales         Arrawarra Headland       Surfing
# 4                  Colima                   La Ticla   Free diving
# 5         New South Wales         Flat Rock, Ballina  Kite surfing
# 15  Eastern Cape Province  Nahoon Beach, East London       Surfing
# 16        New South Wales     Sharpes Beach, Ballina       Surfing
#
#               Name Sex  Age  \
# 3             male   M  NaN
# 4   Gustavo Ramos    M  NaN
# 5          Chris
#    M  NaN
# 15            male   M  NaN
# 16            male   M  NaN
#
#                                                Injury Fatal(Y/N)   Time  \
# 3                           Minor injury to lower leg          N    NaN
# 4   Lacerations to leg & hand shark PROVOKED INCIDENT          N    NaN
# 5                             No injury, board bitten          N    NaN
# 15                       Minor injury, marks on board          N  11h00
# 16                       No injury, surfboard damaged          N  10h30
#
#                             Species               InvestigatorOrSource  \
# 3                         2 m shark                     B. Myatt, GSAF
# 4                   Tiger shark, 3m                          A .Kipper
# 5                               NaN          Daily Telegraph, 6/4/2018
# 15                              NaN  B.Jacob, Dispatch Live, 5/12/2018
# 16  Shark involvement not confirmed                     B. Myatt, GSAF
#
#                             Pdf  \
# 3      2018.06.08-Arrawarra.pdf
# 4          2018.06.04-Ramos.pdf
# 5     2018.06.03.b-FlatRock.pdf
# 15    2018.05.12-EastLondon.pdf
# 16  2018.05.09-SharpesBeach.pdf
#
#                                           HrefFormula  \
# 3   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5   http://sharkattackfile.net/spreadsheets/pdf_di...
# 15  http://sharkattackfile.net/spreadsheets/pdf_di...
# 16  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                  Href  CaseNumber.1  \
# 3   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# 5   http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.b
# 15  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.12
# 16  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.09
#
#     CaseNumber.2  OriginalOrder
# 3     2018.06.08         6300.0
# 4     2018.06.04         6299.0
# 5   2018.06.03.b         6298.0
# 15    2018.05.12         6288.0
# 16    2018.05.09         6287.0

# %% [markdown]
# BUSCAMOS LOS VALORES INCONSISTENTES,NAN Y AQUELLOS QUE NO CUMPLEN EL TYPE CORRECTO EN ESTE CASO NUMERICO.

# %%
data1.Age.unique()
# Out:
# array(['57', '11', '48', nan, '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24',
#        '26', '49', '22', '7', '31', '17', '40', '13', '42', '3', '8',
#        '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18 months', '53',
#        '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
#        '12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
#        '8 or 10', '84', '\xa0 ', ' ', '30 or 36', '6½', '21 & ?', '75',
#        '33 or 37', 'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28',
#        '20?', "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly',
#        'mid-20s', 'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50',
#        '18 to 22', 'adult', '9 & 12', '? & 19', '9 months', '25 to 35',
#        '23 & 26', '1', '(adult)', '33 & 37', '25 or 28',
#        '37, 67, 35, 27,  ? & 27', '21, 34,24 & 35', '30 & 32', '50 & 30',
#        '17 & 35', 'X', '"middle-age"', '13 or 18', '34 & 19', '33 & 26',
#        '2 to 3 months', 'MAKE LINE GREEN', ' 43', '81', '"young"',
#        '7 or 8', '78', '17 & 16', 'F', 'Both 11', '9 or 10', 'young',
#        '36 & 23', '  ', 'A.M.', '?    &   14', '10 or 12', '31 or 33',
#        '2½', '13 or 14'], dtype=object)

# %% [markdown]
# ## IMPORTANTE SUSTITUIR DATOS NULOS,
# Ceros o unknown o lo que corresponda, en caso de no hacerlo un valor NAN es un impar y a la hora de aplicar funciones de limpieza no
# iteraran y rompera el codigo.

# %%
data1.Age.fillna('Unknown',inplace = True) # ANTES DE APLICAR DE CUALQUIER FUNCIÓN REEMPLAZAR LOS VALORES NAN POR 'UNKNOWN'

# %%
data1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  Unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  Unknown
#
#                                               Injury Fatal(Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...          N
# 1                         Minor injury to left thigh          N
# 2       Injury to left lower leg from surfboard skeg          N
# 3                          Minor injury to lower leg          N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT          N
#
#             Time          Species            InvestigatorOrSource  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         Pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                          HrefFormula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 Href CaseNumber.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   CaseNumber.2  OriginalOrder
# 0   2018.06.25         6303.0
# 1   2018.06.18         6302.0
# 2   2018.06.09         6301.0
# 3   2018.06.08         6300.0
# 4   2018.06.04         6299.0

# %% [markdown]
# Creamos y aplicamos una función que repita un patrón de limpieza y nos devuelva datos limpios, consistentes y enteros

# %%
def limpiar_Age(x):
    
    if ',' in x:
        x = x.split(' , ')
        return  x[0]
    

    if '&' in x:
        x = x.split(' & ')
        return x[1]
    
    if 's' in x:
        return x[1]
    
    if 'teen' in x.lower():
        return 15
    
    if 'or' in x:
        x = x.split(' or ')
        return x[1]
    
    if 'adult' in x:
          return 35
          
    if 'Elderly' in x:
          return 70

    if 'young' in x:
          return 22
        
    if 'middle-age' in x:
          return 22
        
    if 'months' in x:
          return 1
    
    if ' ' in x:
          return 'Unknown'
        
    if '?' in x:
          return 'Unknown'
        
    return x

# %% [markdown]
# APLICAMOS LA FUNCION creada anteriormente en funcion a patrones encontrados en la lista de valores unicos.
#
# df[nombrecolumna] = df.nombrecolumna.apply(nombrefuncion)

# %%
data1['Age']=data1.Age.apply(limpiar_Age)

# %%
data1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex      Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F       57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F       11
# 2                    Habush, Oahu      Surfing      John Denges   M       48
# 3              Arrawarra Headland      Surfing             male   M  Unknown
# 4                        La Ticla  Free diving   Gustavo Ramos    M  Unknown
#
#                                               Injury Fatal(Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...          N
# 1                         Minor injury to left thigh          N
# 2       Injury to left lower leg from surfboard skeg          N
# 3                          Minor injury to lower leg          N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT          N
#
#             Time          Species            InvestigatorOrSource  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         Pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                          HrefFormula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 Href CaseNumber.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   CaseNumber.2  OriginalOrder
# 0   2018.06.25         6303.0
# 1   2018.06.18         6302.0
# 2   2018.06.09         6301.0
# 3   2018.06.08         6300.0
# 4   2018.06.04         6299.0

# %%
data1.Age.unique()
# Out:
# array(['57', '11', '48', 'Unknown', '18', '52', '15', '12', '32', '10',
#        '21', '34', '30', '60', '33', '29', '54', '41', '37', '56', '19',
#        '25', '69', '38', '55', '35', '46', '45', '14', '0', '28', '20',
#        '24', '26', '49', '22', '7', '31', '17', '40', '13', '42', '3',
#        '8', '50', '16', '82', '73', '68', '51', '39', '58', 15, '47',
#        '61', '65', '36', '66', '43', '9', '72', '59', '6', '27', '64',
#        '23', '71', '44', '62', '63', '70', '53', '77', '74', '5', '86',
#        '28, 23 & 30', 'e', '84', '6½', '?', '75', 'i', '   31', '87',
#        '67', 70, '>50', 35, ' ', '1', '37, 67, 35, 27,  ? & 27',
#        '21, 34,24 & 35', 'X', 22, '81', '78', 'F', 'A.M.', '  14', '2½'],
#       dtype=object)

# %% [markdown]
# ¿ QUE CANTIDAD DE VALORES INCONSISTENTES TENEMOS DE CADA UNO DE LOS VALORES QUE TENEMOS EN TOTAL EN LA COLUMNA?

# %%
data1.Age.value_counts().head()
# Out:
# Unknown    2848
# 17          154
# 18          151
# 19          144
# 20          143
# Name: Age, dtype: int64

# %% [markdown]
# REEMPLAZAR
#
# Al haber valores inconsistentes en la columna que solo aparecen una sola vez, realizar un bucle para un solo caso no tiene sentido,por lo tanto se deberian reemplazar manualmente
#
# df[nombrecolumna] = df.nombrecolumna.str.replace('datoviejo','datonuevo')

# %%
data1['Age'] = data1.Age.str.replace('28, 23 & 30','26')
data1['Age'] = data1.Age.str.replace('21, 34,24 & 35','28')
data1['Age'] = data1.Age.str.replace('21, 34,24 & 35','28')
data1['Age'] = data1.Age.str.replace('  14','14')
data1['Age'] = data1.Age.str.replace('   31','31')
data1['Age'] = data1.Age.str.replace('6½','6')
data1['Age'] = data1.Age.str.replace('>50','60')
data1['Age'] = data1.Age.str.replace('i','Unknown')
data1['Age'] = data1.Age.str.replace('X','Unknown')
data1['Age'] = data1.Age.str.replace('F','Unknown')
data1['Age'] = data1.Age.str.replace('A.M','Unknown')
data1['Age'] = data1.Age.str.replace('2½','Unknown')        
data1['Age'] = data1.Age.str.replace('e','Unknown')    
data1['Age'] = data1.Age.str.replace('37, 67, 35, 27,  ? & 27','39')
data1['Age'] = data1.Age.str.replace('?' ,'Unknown')
data1['Age'] = data1.Age.str.replace(' ' ,'Unknown')
data1['Age'] = data1.Age.str.replace('Unknown.','Unknown')

# %%
data1.Age.unique()
# Out:
# array(['57', '11', '48', 'Unknown', '18', '52', '15', '12', '32', '10',
#        '21', '34', '30', '60', '33', '29', '54', '41', '37', '56', '19',
#        '25', '69', '38', '55', '35', '46', '45', '14', '0', '28', '20',
#        '24', '26', '49', '22', '7', '31', '17', '40', '13', '42', '3',
#        '8', '50', '16', '82', '73', '68', '51', '39', '58', nan, '47',
#        '61', '65', '36', '66', '43', '9', '72', '59', '6', '27', '64',
#        '23', '71', '44', '62', '63', '70', '53', '77', '74', '5', '86',
#        '84', '75', '87', '67', '1',
#        '37,Unknown7,Unknown5,Unknown7,UnknownnknownUnknownnknown&Unknown7',
#        '81', '78'], dtype=object)

# %%
data1[data1['Age']=='37, 67, 35, 27,  ? & 27'].head() # ¿ EN QUE INDICE ESTA EL VALOR DE EDAD = 'xxx'
# Out:
# Empty DataFrame
# Columns: [CaseNumber, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal(Y/N), Time, Species, InvestigatorOrSource, Pdf, HrefFormula, Href, CaseNumber.1, CaseNumber.2, OriginalOrder]
# Index: []

# %%
data1.loc[3986,'Age'] = '39'

# %%
data1.Age.unique()
# Out:
# array(['57', '11', '48', 'Unknown', '18', '52', '15', '12', '32', '10',
#        '21', '34', '30', '60', '33', '29', '54', '41', '37', '56', '19',
#        '25', '69', '38', '55', '35', '46', '45', '14', '0', '28', '20',
#        '24', '26', '49', '22', '7', '31', '17', '40', '13', '42', '3',
#        '8', '50', '16', '82', '73', '68', '51', '39', '58', nan, '47',
#        '61', '65', '36', '66', '43', '9', '72', '59', '6', '27', '64',
#        '23', '71', '44', '62', '63', '70', '53', '77', '74', '5', '86',
#        '84', '75', '87', '67', '1', '81', '78'], dtype=object)

# %%
import re

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Age                       21
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# Species                 2838
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %%
data1[data1['Age'].isna()].head()
# Out:
#        CaseNumber         Date    Year        Type Country            Area  \
# 182    2017.01.22  22-Jan-2017  2017.0  Unprovoked     USA         Florida
# 294  2016.03.28.b  28-Mar-2016  2016.0  Unprovoked     USA         Florida
# 526    2014.07.27  27-Jul-2014  2014.0  Unprovoked     USA  North Carolina
# 567  2014.04.04.b  04-Apr-2014  2014.0  Unprovoked     USA         Florida
# 568  2014.04.04.a  04-Apr-2014  2014.0  Unprovoked     USA         Florida
#
#                              Location  Activity       Name Sex  Age  \
# 182   Vero Beach, Indian River County       NaN       male   M  NaN
# 294      Fort Myers Beach, Lee County       NaN  Nick Kawa   M  NaN
# 526    Sunset Beach, Brunswick County  Swimming       male   M  NaN
# 567  New Smyrna Beach, Volusia County   Surfing       male   M  NaN
# 568  New Smyrna Beach, Volusia County   Surfing       male   M  NaN
#
#                                                 Injury Fatal(Y/N)   Time  \
# 182               Puncture wounds to lower arm or hand          N  14h00
# 294  Minor injury to arm. Possibly caused by smalll...        NaN    NaN
# 526                                   Left foot bitten          N    NaN
# 567            Minor puncture wounds to lower left leg          N  13h50
# 568                                Lacerations to foot          N  13h30
#
#                              Species InvestigatorOrSource  \
# 182                              NaN    TCPalm, 1/22/2017
# 294  Shark involvement not confirmed    Fox 35, 3/30/2015
# 526    Possibly juvenile tiger shark    C. Creswell, GSAF
# 567                              NaN    News 13, 4/4/2014
# 568                              NaN    News 13, 4/4/2014
#
#                             Pdf  \
# 182    2017.01.22-VeroBeach.pdf
# 294       2016.03.28.b-Kawa.pdf
# 526  2014.07.27-SunsetBeach.pdf
# 567        2014.04.04.b-NSB.pdf
# 568        2014.04.04.a-NSB.pdf
#
#                                            HrefFormula  \
# 182  http://sharkattackfile.net/spreadsheets/pdf_di...
# 294  http://sharkattackfile.net/spreadsheets/pdf_di...
# 526  http://sharkattackfile.net/spreadsheets/pdf_di...
# 567  http://sharkattackfile.net/spreadsheets/pdf_di...
# 568  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   Href  CaseNumber.1  \
# 182  http://sharkattackfile.net/spreadsheets/pdf_di...    2017.01.22
# 294  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.03.28.b
# 526  http://sharkattackfile.net/spreadsheets/pdf_di...    2014.07.27
# 567  http://sharkattackfile.net/spreadsheets/pdf_di...  2014.04.04.b
# 568  http://sharkattackfile.net/spreadsheets/pdf_di...  2014.04.04.a
#
#      CaseNumber.2  OriginalOrder
# 182    2017.01.22         6121.0
# 294  2016.03.28.b         6009.0
# 526    2014.07.27         5777.0
# 567  2014.04.04.b         5736.0
# 568  2014.04.04.a         5735.0

# %%
data1.Age.fillna('Unknown',inplace = True)

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# Species                 2838
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %%
keyword='Unknown'
data_prueba = data1[data1.Age.str.contains(keyword, regex=True)]

# %%
data_prueba.Age.value_counts()
# Out:
# Unknown    2879
# Name: Age, dtype: int64

# %%
data1.Age.unique()
# Out:
# array(['57', '11', '48', 'Unknown', '18', '52', '15', '12', '32', '10',
#        '21', '34', '30', '60', '33', '29', '54', '41', '37', '56', '19',
#        '25', '69', '38', '55', '35', '46', '45', '14', '0', '28', '20',
#        '24', '26', '49', '22', '7', '31', '17', '40', '13', '42', '3',
#        '8', '50', '16', '82', '73', '68', '51', '39', '58', '47', '61',
#        '65', '36', '66', '43', '9', '72', '59', '6', '27', '64', '23',
#        '71', '44', '62', '63', '70', '53', '77', '74', '5', '86', '84',
#        '75', '87', '67', '1', '81', '78'], dtype=object)

# %%
data1.Age.value_counts().head()
# Out:
# Unknown    2879
# 17          154
# 18          151
# 19          144
# 20          143
# Name: Age, dtype: int64

# %% [markdown]
# ###  IMPORTANTE , Sustituir los valores 'object' para poder realizar operaciones aritmeticas

# %% [markdown]
# SUSTITUIR, EN ESTE CASO, LOS VALORES UNKNOWN POR LA MEDIANA DE LOS VALORES DIFERENTES A 'UNKNOWN'

# %%
data1.Age[data1.Age!='Unknown'].median()
# Out:
# 24.0

# %%
data1['Age'] = data1.Age.str.replace('Unknown','24')

# %%
data1.Age.unique()
# Out:
# array(['57', '11', '48', '24', '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '0', '28', '20', '26',
#        '49', '22', '7', '31', '17', '40', '13', '42', '3', '8', '50',
#        '16', '82', '73', '68', '51', '39', '58', '47', '61', '65', '36',
#        '66', '43', '9', '72', '59', '6', '27', '64', '23', '71', '44',
#        '62', '63', '70', '53', '77', '74', '5', '86', '84', '75', '87',
#        '67', '1', '81', '78'], dtype=object)

# %% [markdown]
# FILTRO ¿EN QUE FILAS DE LA COLUMNA AGE APARECE EL 24?

# %%
data1.Age[data1.Age=='24'].head() # FILTRO EN QUE FILAS DE LA COLUMNA AGE ESTA EL 24
# Out:
# 3     24
# 4     24
# 5     24
# 15    24
# 16    24
# Name: Age, dtype: object

# %%
data1.Age[data1.Age == object ].head()
# Out:
# Series([], Name: Age, dtype: object)

# %%
data1['Age'].mean()
# Out:
# inf

# %% [markdown]
# ### Species
#
# Comprobamos que en la columna 'Species' hay 2838 valores nulos

# %%
nan_cols = data.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# Species                 2838
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %%
data1[data1['Species'].isna()].head()
# Out:
#       CaseNumber         Date    Year        Type    Country             Area  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 5   2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 9   2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
# 11    2018.05.21  21-May-2018  2018.0  Unprovoked        USA   South Carolina
#
#                              Location         Activity             Name Sex  \
# 1      St. Simon Island, Glynn County         Standing  Adyson McNeely    F
# 2                        Habush, Oahu          Surfing      John Denges   M
# 5                  Flat Rock, Ballina     Kite surfing          Chris
#    M
# 9       Daytona Beach, Volusia County         Standing             male   M
# 11  Isle of Palms,  Charleston County  Boogie boarding     Trey de Boer   M
#
#    Age                                        Injury Fatal(Y/N)  \
# 1   11                    Minor injury to left thigh          N
# 2   48  Injury to left lower leg from surfboard skeg          N
# 5   24                       No injury, board bitten          N
# 9   12                          Minor injury to foot          N
# 11  10          Injuries to lower right leg and foot          N
#
#              Time Species              InvestigatorOrSource  \
# 1   14h00  -15h00     NaN    K.McMurray, TrackingSharks.com
# 2           07h45     NaN    K.McMurray, TrackingSharks.com
# 5             NaN     NaN         Daily Telegraph, 6/4/2018
# 9           14h00     NaN  K. McMurray, Tracking Sharks.com
# 11            NaN     NaN                 C. Creswell, GSAF
#
#                               Pdf  \
# 1          2018.06.18-McNeely.pdf
# 2           2018.06.09-Denges.pdf
# 5       2018.06.03.b-FlatRock.pdf
# 9   2018.05.26.a-DaytonaBeach.pdf
# 11          2018.05.21-deBoer.pdf
#
#                                           HrefFormula  \
# 1   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5   http://sharkattackfile.net/spreadsheets/pdf_di...
# 9   http://sharkattackfile.net/spreadsheets/pdf_di...
# 11  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                  Href  CaseNumber.1  \
# 1   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 5   http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.b
# 9   http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.a
# 11  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.21
#
#     CaseNumber.2  OriginalOrder
# 1     2018.06.18         6302.0
# 2     2018.06.09         6301.0
# 5   2018.06.03.b         6298.0
# 9   2018.05.26.a         6294.0
# 11    2018.05.21         6292.0

# %% [markdown]
# CONVERTIMOS LOS VALOS NAN EN 'UNKNOWN' PARA PODER APLICAR FUNCIONES

# %%
data1['Species'].fillna('Unknown',inplace = True) # ANTES DE APLICAR DE CUALQUIER FUNCIÓN REEMPLAZAR LOS VALORES NAN POR 'UNKNOWN'

# %% [markdown]
# ¿QUE VALORES/OBJETOS TENEMOS EN LA COLUMNA SPECIES? BUSCAMOS INCONSISTENTES

# %%
pd.set_option('display.max_rows', None)

# %%
data1.Species.unique()
# Out:
# array(['White shark', 'Unknown', '2 m shark', ..., "12' tiger shark",
#        'Blue pointers',
#        'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable'],
#       dtype=object)

# %% [markdown]
# ¿QUE CANTIDAD DE VALORES SON INCONSISTENTES Y POR LO TANTO TENEMOS QUE MODIFICAR ?

# %%
data1.Species.value_counts()
# Out:
# Unknown                                                                                                                                                                                                 2839
# White shark                                                                                                                                                                                              163
# Shark involvement prior to death was not confirmed                                                                                                                                                       105
# Invalid                                                                                                                                                                                                  102
# Shark involvement not confirmed                                                                                                                                                                           88
# Tiger shark                                                                                                                                                                                               73
# Shark involvement prior to death unconfirmed                                                                                                                                                              68
# Bull shark                                                                                                                                                                                                52
# 4' shark                                                                                                                                                                                                  40
# 6' shark                                                                                                                                                                                                  40
# Questionable incident                                                                                                                                                                                     35
# 1.8 m [6'] shark                                                                                                                                                                                          35
# Questionable                                                                                                                                                                                              34
# 1.5 m [5'] shark                                                                                                                                                                                          32
# 1.2 m [4'] shark                                                                                                                                                                                          27
# 3' shark                                                                                                                                                                                                  26
# 5' shark                                                                                                                                                                                                  26
# 2 m shark                                                                                                                                                                                                 25
# 4' to 5' shark                                                                                                                                                                                            24
# 3 m [10'] shark                                                                                                                                                                                           22
# Wobbegong shark                                                                                                                                                                                           21
# No shark involvement                                                                                                                                                                                      21
# 3' to 4' shark                                                                                                                                                                                            18
# 3 m shark                                                                                                                                                                                                 17
# 2.4 m [8'] shark                                                                                                                                                                                          16
# 3.7 m [12'] shark                                                                                                                                                                                         15
# Blacktip shark                                                                                                                                                                                            15
# 12' shark                                                                                                                                                                                                 15
# Blue shark                                                                                                                                                                                                14
# 1.2 m to 1.5 m [4' to 5'] shark                                                                                                                                                                           14
# 7' shark                                                                                                                                                                                                  13
# 1.5 m shark                                                                                                                                                                                               13
# Mako shark                                                                                                                                                                                                13
# "a small shark"                                                                                                                                                                                           13
# Shark involvement prior to death not confirmed                                                                                                                                                            13
# Raggedtooth shark                                                                                                                                                                                         12
# Bronze whaler shark                                                                                                                                                                                       12
# 10' shark                                                                                                                                                                                                 12
# 6 m [20'] white shark                                                                                                                                                                                     12
# Nurse shark                                                                                                                                                                                               12
# 5 m [16.5'] white shark                                                                                                                                                                                   12
# Zambesi shark                                                                                                                                                                                             11
# Grey nurse shark                                                                                                                                                                                          11
# 4 m [13'] white shark                                                                                                                                                                                     10
# Hammerhead shark                                                                                                                                                                                           9
# 1 m shark                                                                                                                                                                                                  9
# a small shark                                                                                                                                                                                              9
# 2.1 m [7'] shark                                                                                                                                                                                           9
# White shark, 4 m [13']                                                                                                                                                                                     9
# 2' to 3' shark                                                                                                                                                                                             8
# "small shark"                                                                                                                                                                                              8
# 3 m [10'] white shark                                                                                                                                                                                      8
# Unidentified species                                                                                                                                                                                       8
# 8' shark                                                                                                                                                                                                   7
# Bull shark, 6'                                                                                                                                                                                             7
# Lemon shark                                                                                                                                                                                                7
# 9' shark                                                                                                                                                                                                   7
# Basking shark                                                                                                                                                                                              7
# 2.5 m shark                                                                                                                                                                                                7
# Sandtiger shark                                                                                                                                                                                            7
# 1.8 m shark                                                                                                                                                                                                7
# White shark, 3 m [10']                                                                                                                                                                                     6
# Tiger shark?                                                                                                                                                                                               6
# 6' to 8' shark                                                                                                                                                                                             6
# 14' shark                                                                                                                                                                                                  6
# Oceanic whitetip shark                                                                                                                                                                                     6
# 4 m to 5 m [13' to 16.5'] white shark                                                                                                                                                                      6
#                                                                                                                                                                                                            6
# White shark, 5 m [16.5']                                                                                                                                                                                   6
# Spinner shark                                                                                                                                                                                              6
# Thought to involve a Zambesi shark                                                                                                                                                                         6
# 2.5 m [8.25'] white shark                                                                                                                                                                                  6
# 5' to 6' shark                                                                                                                                                                                             6
# White shark, 3.5 m                                                                                                                                                                                         6
# 4 m [13'] shark                                                                                                                                                                                            5
# 1.8 m [6'] blacktip shark                                                                                                                                                                                  5
# 4.3 m [14'] shark                                                                                                                                                                                          5
# 15' shark                                                                                                                                                                                                  5
# 5 m to 6 m [16.5' to 20'] white shark                                                                                                                                                                      5
# Blacktip or spinner shark                                                                                                                                                                                  5
# 5.5 m [18'] white shark                                                                                                                                                                                    5
# 13' shark                                                                                                                                                                                                  5
# Angel shark                                                                                                                                                                                                5
# 1.8 m to 2.4 m [6' to 8'] shark                                                                                                                                                                            5
# 4.6 m [15'] shark                                                                                                                                                                                          5
# Grey reef shark                                                                                                                                                                                            5
# small shark                                                                                                                                                                                                5
# 2' shark                                                                                                                                                                                                   5
# "sand shark"                                                                                                                                                                                               5
# Tiger shark, 3 m [10']                                                                                                                                                                                     5
# 0.9 m [3'] shark                                                                                                                                                                                           5
# Possibly a juvenile blacktip or spinner shark                                                                                                                                                              5
# 3 m [10'] bull shark                                                                                                                                                                                       5
# Tiger shark, 1.8 m to 2.4 m [6' to 8']                                                                                                                                                                     4
# 2 m [6.75'] shark                                                                                                                                                                                          4
# 5.5 m [18'] shark                                                                                                                                                                                          4
# Galapagos shark                                                                                                                                                                                            4
# blacktip or spinner shark                                                                                                                                                                                  4
# 2.7 m [9'] shark                                                                                                                                                                                           4
# 4 m shark                                                                                                                                                                                                  4
# Thought to involve a white shark                                                                                                                                                                           4
# 12' to 14' shark                                                                                                                                                                                           4
# White shark?                                                                                                                                                                                               4
# 20' shark                                                                                                                                                                                                  4
# White sharks                                                                                                                                                                                               4
# White shark, 3.7 m [12']                                                                                                                                                                                   4
# White shark, 2.4 m [8']                                                                                                                                                                                    4
# 2m shark                                                                                                                                                                                                   4
# 4' to 6' shark                                                                                                                                                                                             4
# Tiger shark, 14'                                                                                                                                                                                           4
# Tiger shark, 12'                                                                                                                                                                                           4
# Sevengill shark                                                                                                                                                                                            4
# Shark involvement questionable                                                                                                                                                                             4
# Shark involvement suspected but not confirmed                                                                                                                                                              4
# 1.5 m to 1.8 m [5' to 6'] shark                                                                                                                                                                            4
# White shark, 8' to 10'                                                                                                                                                                                     4
# Caribbean reef shark                                                                                                                                                                                       4
# Bull shark, 2m                                                                                                                                                                                             3
# White shark, 10'                                                                                                                                                                                           3
# a small shark'                                                                                                                                                                                             3
# Tiger shark, 1.8 m [6']                                                                                                                                                                                    3
# Tiger shark, 2.4 m to 3 m [8' to 10']                                                                                                                                                                      3
# Bull shark suspected due to freshwater habitat                                                                                                                                                             3
# Nurse shark, 1.5 m [5']                                                                                                                                                                                    3
# bull shark                                                                                                                                                                                                 3
# Tiger shark, 1.8 m [6']                                                                                                                                                                                    3
# Bull or tiger shark                                                                                                                                                                                        3
# "a dog shark"                                                                                                                                                                                              3
# 18" to 24" shark                                                                                                                                                                                           3
# 16' shark                                                                                                                                                                                                  3
# 10' to 12' shark                                                                                                                                                                                           3
# Tiger shark, 10'                                                                                                                                                                                           3
# 2 m [6'9"] shark                                                                                                                                                                                           3
# 5 m shark                                                                                                                                                                                                  3
# 6 m shark                                                                                                                                                                                                  3
# 3.5 m shark                                                                                                                                                                                                3
# White shark, 4.5 m                                                                                                                                                                                         3
# reef shark?                                                                                                                                                                                                3
# Unidentified                                                                                                                                                                                               3
# "A small shark"                                                                                                                                                                                            3
# 3.5 m white shark                                                                                                                                                                                          3
# "small sharks"                                                                                                                                                                                             3
# 4 m white shark                                                                                                                                                                                            3
# Lemon shark, 4'                                                                                                                                                                                            3
# Bull shark, 4' to 5'                                                                                                                                                                                       3
# White shark, 4m                                                                                                                                                                                            3
# White shark, 5m                                                                                                                                                                                            3
# White shark, 2.5 m                                                                                                                                                                                         3
# Tiger shark, 10' to 12'                                                                                                                                                                                    3
# 4.5 m white shark                                                                                                                                                                                          3
# White shark, 3m to 4m                                                                                                                                                                                      3
# 3.5' to 4' shark                                                                                                                                                                                           3
# Tiger shark, 3.7 m [12']                                                                                                                                                                                   3
# White shark, 4 m                                                                                                                                                                                           3
# Tiger shark, 3 m                                                                                                                                                                                           3
# Blue pointer                                                                                                                                                                                               3
# 18' shark                                                                                                                                                                                                  3
# 7-gill shark                                                                                                                                                                                               3
# Bronze whaler shark?                                                                                                                                                                                       3
# 3 sharks                                                                                                                                                                                                   3
# Tiger shark, 5 m [16.5']                                                                                                                                                                                   3
# White shark, 15'                                                                                                                                                                                           3
# Blacktip shark, 4'                                                                                                                                                                                         3
# 3 m to 4 m [10' to 13'] white shark                                                                                                                                                                        3
# Bronze whaler shark, 2.5 m [8.25']                                                                                                                                                                         3
# White shark, 3 m                                                                                                                                                                                           3
# White shark, 4 m to 5 m [13' to 16.5']                                                                                                                                                                     3
# 6 m [20'] shark                                                                                                                                                                                            3
# Wobbegong shark?                                                                                                                                                                                           3
# 3' to 5' shark                                                                                                                                                                                             3
# Bronze whaler shark, 6'                                                                                                                                                                                    3
# 2.4 m [8']  shark                                                                                                                                                                                          3
# 2 m to 3 m shark                                                                                                                                                                                           3
# Questionable Incident                                                                                                                                                                                      3
# Bronze whaler shark, 3 m [10']                                                                                                                                                                             3
# 2.3 m [7'] shark                                                                                                                                                                                           3
# Tiger shark, 2.4 m [8']                                                                                                                                                                                    3
# juvenile shark                                                                                                                                                                                             3
# "a large shark"                                                                                                                                                                                            2
# White shark, 3 to 3.5m                                                                                                                                                                                     2
# A pack of 6 sharks                                                                                                                                                                                         2
# small blacktip shark?                                                                                                                                                                                      2
# White shark, 3.6 m [11'9"]                                                                                                                                                                                 2
# Nurse shark, 2.1 m [7']                                                                                                                                                                                    2
# White shark, 3 m                                                                                                                                                                                           2
# White shark, 4.9 m [16']                                                                                                                                                                                   2
# A small shark                                                                                                                                                                                              2
# "sand" shark                                                                                                                                                                                               2
# 200-lb shark                                                                                                                                                                                               2
# Raggedtooth shark, 1.2 m [4']                                                                                                                                                                              2
# White shark (tooth fragment recovered)                                                                                                                                                                     2
# White shark, 3.5m                                                                                                                                                                                          2
# 20 to 30kg shark                                                                                                                                                                                           2
# Wobbegong shark, 1.2 m [4']                                                                                                                                                                                2
# Raggedtooth shark, 1.5 m [5']                                                                                                                                                                              2
# Tiger shark, 6'                                                                                                                                                                                            2
# 3.5 m [11.5'] white shark                                                                                                                                                                                  2
# Tiger shark, 1.5 m to 1.8 m [5' to 6']                                                                                                                                                                     2
# Raggedtooth shark                                                                                                                                                                                          2
# Bronze whaler shark, 2.5 m [8.25']  k                                                                                                                                                                      1
# Spinner shark, 1.2 m to 1.5 m [4' to 5']                                                                                                                                                                   1
# 1.9 m [6.5'] bull shark                                                                                                                                                                                    1
# 1 m shark, possibly whitetip reef shark                                                                                                                                                                    1
# Possibly a 1.5 m [5'] blacktip or spinner shark                                                                                                                                                            1
# White shark, 2.7 m to 3 m [9' to 10']                                                                                                                                                                      1
# 1.2 m to 1.5 m [4.5' to 5'] shark                                                                                                                                                                          1
# Bull shark, 2.3 m [7.5']                                                                                                                                                                                   1
# 0.9 m  [3'] shark                                                                                                                                                                                          1
# Mako shark, 14'                                                                                                                                                                                            1
# Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable                                                                              1
# Name: Species, dtype: int64

# %% [markdown]
# Creamos y aplicamos un funcion de limpieza de datos en función a unos patrones de iteracion que se repiten a lo largo de los datos inconsistentes

# %%
def limpiar_tiburones(x):
    
    if 'tiger' in x.lower():
        return 'Tiger shark'
    if 'white' in x.lower():
        return 'White shark'
    if 'bull' in x.lower():
        return 'Bull shark'
    if 'nurse' in x.lower():
        return 'Nurse shark'
    if 'blacktip' in x.lower():
        return 'Blacktip Shark'
    if 'blue' in x.lower():
        return 'Blue Shark'
    if 'mako' in x.lower():
        return 'Mako Shark'
    if 'wobbegong' in x.lower():
        return 'Wobbegong Shark'
    if 'hammerhead' in x.lower():
        return 'Hammerhead Shark'
    if 'raggedtooth' in x.lower():
        return 'Raggedtooth Shark'
    if 'lemon' in x.lower():
        return 'Lemon Shark'
    if 'zambesi' in x.lower():
        return 'Zambesi Shark'
    if 'spinner' in x.lower():
        return 'Spinner Shark'
    
    

    return 'Unknown'

# %% [markdown]
# APLICAMOS LA FUNCION creada anteriormente en funcion a patrones encontrados en la lista de valores unicos.
#
# df[nombrecolumna] = df.nombrecolumna.apply(nombrefuncion)

# %%
data1['Species']=data1['Species'].apply(limpiar_tiburones)

# %%
data1['Species'].value_counts()
# Out:
# Unknown              4641
# White shark           665
# Tiger shark           285
# Bull shark            178
# Blacktip Shark        101
# Nurse shark            97
# Blue Shark             56
# Mako Shark             54
# Wobbegong Shark        50
# Hammerhead Shark       48
# Raggedtooth Shark      43
# Lemon Shark            34
# Zambesi Shark          29
# Spinner Shark          21
# Name: Species, dtype: int64

# %% [markdown]
# ### Time
#
# Comprobamos que en la columna 'species' hay3358 valores nulos

# %% [markdown]
# Lineas de codigo basicas de busqueda/modificacion
#
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?
#
# nan_cols = data.isna().sum()
# nan_cols[nan_cols>0]
#
#
# 2º ¿En que fila estan estos nulos? Contextualizamos con la informacion en el resto de columnas
#
# data[data['nombrecolumna'].isna()]
#
# 3º) SUSTITUIR NULOS por 'Unknown' ceros .... Para poder pasarle la lista de valores a la funcion, nan no interan
#
# data1.nombrecolumna.fillna('Unknown',inplace = True)
# data1.nombrecolumna.fillna(0,inplace = True)
#
#
# 4º ¿ QUE VALORES/OBJETOS HAY en esa columna? Buscamos valores nan y/o inconsistente
#
# data.nombrecolumna.unique()
#
#
# 5º ¿ CUANTOS valores/objetos/elementos hay en esa columna? Buscamos la CANTIDAD de valores inconsistentes
#
# data1.Age.value_counts()

# %%
nan_cols = data1.isna().sum() # COMPROBACION DE LAS COLUMNAS CON VALORES NULOS AUN 
nan_cols[nan_cols>0]
# Out:
# Location                 540
# Activity                 544
# Name                     210
# Sex                      565
# Injury                    28
# Fatal(Y/N)               539
# Time                    3354
# InvestigatorOrSource      17
# HrefFormula                1
# dtype: int64

# %%
data1[data1['Time'].isna()].head() # DATAFRAME SOLO DE LOS VALORES CON TIME = NAN
# Out:
#       CaseNumber         Date    Year        Type    Country             Area  \
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5   2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 7     2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 11    2018.05.21  21-May-2018  2018.0  Unprovoked        USA   South Carolina
#
#                                              Location         Activity  \
# 3                                  Arrawarra Headland          Surfing
# 4                                            La Ticla      Free diving
# 5                                  Flat Rock, Ballina     Kite surfing
# 7   Lighhouse Point Park, Ponce Inlet, Volusia County          Fishing
# 11                  Isle of Palms,  Charleston County  Boogie boarding
#
#               Name Sex Age                                             Injury  \
# 3             male   M  24                          Minor injury to lower leg
# 4   Gustavo Ramos    M  24  Lacerations to leg & hand shark PROVOKED INCIDENT
# 5          Chris
#    M  24                            No injury, board bitten
# 7             male   M  52            Minor injury to foot. PROVOKED INCIDENT
# 11    Trey de Boer   M  10               Injuries to lower right leg and foot
#
#    Fatal(Y/N) Time      Species             InvestigatorOrSource  \
# 3           N  NaN      Unknown                   B. Myatt, GSAF
# 4           N  NaN  Tiger shark                        A .Kipper
# 5           N  NaN      Unknown        Daily Telegraph, 6/4/2018
# 7           N  NaN  Lemon Shark  K. McMurray, TrackingSharks.com
# 11          N  NaN      Unknown                C. Creswell, GSAF
#
#                           Pdf  \
# 3    2018.06.08-Arrawarra.pdf
# 4        2018.06.04-Ramos.pdf
# 5   2018.06.03.b-FlatRock.pdf
# 7        2018.05.27-Ponce.pdf
# 11      2018.05.21-deBoer.pdf
#
#                                           HrefFormula  \
# 3   http://sharkattackfile.net/spreadsheets/pdf_di...
# 4   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5   http://sharkattackfile.net/spreadsheets/pdf_di...
# 7   http://sharkattackfile.net/spreadsheets/pdf_di...
# 11  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                  Href  CaseNumber.1  \
# 3   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# 5   http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.b
# 7   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.27
# 11  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.21
#
#     CaseNumber.2  OriginalOrder
# 3     2018.06.08         6300.0
# 4     2018.06.04         6299.0
# 5   2018.06.03.b         6298.0
# 7     2018.05.27         6296.0
# 11    2018.05.21         6292.0

# %%
data1['Time'].fillna('99h99',inplace = True)

# %%
data1.Time.unique()
# Out:
# array(['18h00', '14h00  -15h00', '07h45', '99h99', 'Late afternoon',
#        '17h00', '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30',
#        '10h40', '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40',
#        '08h00', '17h35', '15h30', '07h30', '19h00, Dusk', 'Night',
#        '16h00', '15h01', '12h00', '13h45', '23h30', '09h00', '14h30',
#        '18h30', '12h30', '16h30', '18h45', '06h00', '10h00', '10h44',
#        '13h19', 'Midday', '13h30', '10h45', '11h20', '11h45', '19h30',
#        '08h30', '15h45', 'Shortly before 12h00', '17h34', '17h10',
#        '11h15', '08h50', '17h45', '13h00', '10h20', '13h20', '02h00',
#        '09h50', '11h30', '17h30', '9h00', '10h43', 'After noon', '15h15',
#        '15h40', '19h05', '1300', '14h30 / 15h30', '22h00', '16h20',
#        '14h34', '15h25', '14h55', '17h46', 'Morning ', '15h49', '19h00',
#        'Midnight', '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50',
#        '13h50', '19h20', '10h25', '10h45-11h15', '16h45', '15h52',
#        '06h15', '14h40', '19h45', '10h10', '08h45', 'Evening', '12h10',
#        '18h05', '11h41', '12h25', '17h51', '16h12', '12h45', '10h50',
#        '14h15', '09h45', '06h45', '05h00', '03h30',
#        'Sometime between 06h00 & 08hoo', '06h30', '17h20', '20h00',
#        '16h40', '16h18', '11h10', 'Early afternoon', '17h50',
#        '07h00 - 08h00', '18h15-18h30', '17h01', '09h57', '08h20', '17h58',
#        '20h30', '15h19', '10h55', '15h55', '23h00', '12h40', '13h55',
#        '16h05', '14h10', '15h20', '12h50', '14h45', '13h40', '13h24',
#        '09h00 - 09h30', '0830', '11h40', '08h10', '15h56', '14h20',
#        'Just before noon', '07h56', '1600', '17h17', '16h35', '09h05',
#        '07h15', '07h20', '19h28', '12h38', '05h50', '15h50', '11h05',
#        'Early morning', 'Dawn', '05h45', '13h25', '12h20', '13h26',
#        '09h11', '12h15', '13h15', '18h20', '15h35', 'AM', '13h51', 'A.M.',
#        '08h05', '19h15', '10h35', '15h44', 'Dusk', '21h00', 'Lunchtime',
#        '15j45', '09h35', '10h27', '10h16', '0500', 'Before 07h00',
#        '09h20', '10h00 -- 11h00', '12h05', '14h21', '18h50', '15h53',
#        '"Just before 11h00"', '11h115', '13h42', '20h15', '12h39',
#        '07h05', 'Sunset', '  ', '13h05', '11h50', '"Evening"',
#        'Just before sundown', '17h55', '22h30', '17h15', '16h10',
#        '11h30 ', '06h10', '16h15', 'Between 05h00 and 08h00', '07h08',
#        '17h00 or 17h40', '03h00', '>08h00', '--', '12h02', '12h55',
#        '16h14', '17h11', '00h30', '14h37', '10h07', '13h53', '11h55',
#        '13h23', 'Just after 12h00', '02h30', '08h40', '11h56', '14h35',
#        ' ', 'Early Morning', '07h50', 'Shortly after midnight', '14h25',
#        '13h345', '\xa0 ', '06h47', '09h00 -10h00', '20h45 (Sunset)',
#        'Late morning', 'P.M.', '18h40', '13h14', '13h06',
#        'Shortly before 13h00', '12h34', '11h53', '8:04 pm', '12h46',
#        '12h48', '17h42', '12h35', 'Possibly same incident as 2000.08.21',
#        'After Dusk', '11h57', 'Noon', '17h40', '11h25', '18h25', '10h28',
#        '09h15', '14h16', '09h55', '2 hours after Opperman', '15h05',
#        '09h30 ', 'Mid afternoon', 'Mid morning', '11h48', '11h00 / 11h30',
#        '07h19', '13h37', '11h06', '"Night"', '18h30?', '11h58', '11h51',
#        '18h12', '07h10', '07h40', '12h33',
#        '30 minutes after 1992.07.08.a', '>06h45', '15h06', '12h54',
#        'Between 06h00 & 07h20', '16h55', '05h40', '<07h30', '21h30',
#        '17h00 Sunset', 'Nightfall', 'X', '08h57', '18h30 (Sunset)',
#        '06j00', '08h35', '10h22', '02h45', 'Prior to 10h37', 'Daybreak',
#        '18h10', '>12h00', 'Mid-morning', '08h55', '16h30 or 18h00',
#        'Just before dawn', ' 14h00', 'Daytime', '06h50', '01h00', 'Dark',
#        '10h00 / 11h00', '"After lunch"', '07h32', '15h00 or 15h45',
#        '>17h00', '19h00 / 20h00', '12h45 / 13h45', '14h00 - 15h00',
#        'night', '03h45 - 04h00', '13h10', '09h30 / 15h30',
#        '08h00 / 09h30', '19h35', '12h00 to 14h00', '13h35', 'Late night',
#        '01h32', '10h30 or 13h30', '16h23', '15h00j', 'Midday.',
#        '"After dark"', '10h00 or 14h00', '19h10', '16h25',
#        '2 hrs before sunset', '18h15 to 21h30', '1500',
#        '"shortly before dusk"', '>17h30', '>14h30',
#        'Between 11h00 & 12h00', 'After 04h00',
#        '11h01 -time of ship sinking', 'Ship aban-doned at 03h10', '19h55',
#        'After dusk',
#        'FATAL  (Wire netting installed at local beaches after this incident.)',
#        '01h30', 'After midnight', 'Late afternon', '05h30', '08h58',
#        '"Early evening"', 'Late Afternoon', '   ', 'Before daybreak',
#        'dusk', 'Before 10h30', '06h00 -- 07h00', '01h50', '17h00-18h00',
#        '19h00-20h00'], dtype=object)

# %%
data1.Time.value_counts().head()
# Out:
# 99h99        3354
# Afternoon     187
# 11h00         128
# Morning       121
# 12h00         109
# Name: Time, dtype: int64

# %%
def limpiar_Time(x):
    
    if '/' in x:
        x = x.split(' / ')
        return  x[0]
    
    if 'or' in x:
        x = x.split(' or ')
        return  x[0]
    
    if '--' in x:
        x = x.split(' -- ')
        return  x[0]
    
    if 'before' in x.lower():
        x = x.split(' before ')
        return  x[1]
    
    if '-' in x:
        x = x.split(' - ')
        return  x[0]
    
    if 'afternoon' in x.lower():
        return  '19h00'
    
    if 'morning' in x.lower():
        return  '10h00'
    
    if 'Morning ' in x:
        return  '10h00'
    
    if 'night' in x.lower():
        return  '23h00'
    
    if 'night' in x.lower():
        return  '23h00'
    
    if 'evening' in x.lower():
        return  '21h00'
    
    if 'dusk' in x.lower():
        return  '20h00'
    
    if 'midday' in x.lower():
        return  '12h00'
    
    if 'early_afternoon' in x.lower():
        return  '16h00'
    
    if 'sunset' in x.lower():
        return  '20h00'
    
    if 'midnight' in x.lower():
        return  '00h00'
    
    if 'dawn' in x.lower():
        return  '07h00'
    
    if 'dunk' in x.lower():
        return  '20h00'
    
    if 'noon' in x.lower():
        return '12:00'
    
    if 'between' in x.lower():
        x = x.split(' between ')
        return  x[0]
    
   
        
    return x

# %% [markdown]
# APLICAMOS LA FUNCION creada anteriormente en funcion a patrones encontrados en la lista de valores unicos.
#
# df[nombrecolumna] = df.nombrecolumna.apply(nombrefuncion)

# %%
data1['Time']=data1['Time'].apply(limpiar_Time) # APLICAMOS LA FUNCION

# %%
data1['Time'].value_counts().head()
# Out:
# 99h99      3354
# 19h00       256
# 11h00       129
# Morning     121
# 12h00       120
# Name: Time, dtype: int64

# %%
data1.Time[data1.Time == 'Before 10h30' ].head()
# Out:
# 5922    Before 10h30
# Name: Time, dtype: object

# %% [markdown]
# ### Location
#
# Comprobamos que en la columna 'species' hay3358 valores nulos
#
# Lineas de codigo basicas de busqueda/modificacion
#
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?
#
# nan_cols = data.isna().sum()
# nan_cols[nan_cols>0]
#
# 2º ¿En que fila estan estos nulos? Contextualizamos con la informacion en el resto de columnas
#
# data[data['nombrecolumna'].isna()]
#
# 3º) SUSTITUIR NULOS por 'Unknown' ceros .... Para poder pasarle la lista de valores a la funcion, nan no interan
#
# data1.nombrecolumna.fillna('Unknown',inplace = True) data1.nombrecolumna.fillna(0,inplace = True)
#
# 4º ¿ QUE VALORES/OBJETOS HAY en esa columna? Buscamos valores nan y/o inconsistente
#
# data.nombrecolumna.unique()
#
# 5º ¿ CUANTOS valores/objetos/elementos hay en esa columna? Buscamos la CANTIDAD de valores inconsistentes
#
# data1.Age.value_counts()

# %%
nan_cols = data1.isna().sum() # COMPROBACION DE LAS COLUMNAS CON VALORES NULOS AUN 
nan_cols[nan_cols>0]
# Out:
# Location                540
# Activity                544
# Name                    210
# Sex                     565
# Injury                   28
# Fatal(Y/N)              539
# InvestigatorOrSource     17
# HrefFormula               1
# dtype: int64

# %%
data1[data1['Location'].isna()].head() # DATAFRAME SOLO DE LOS VALORES CON TIME = NAN
# Out:
#        CaseNumber                  Date    Year        Type  Country  \
# 56     2017.12.09           09-Dec-2017  2017.0  Unprovoked  BAHAMAS
# 62   2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked  Unknown
# 101    2017.08.18           18-Aug-2017  2017.0  Unprovoked  BAHAMAS
# 110  2017.07.26.R  Reported 26-Jul-2017  2017.0  Unprovoked  BAHAMAS
# 132  2017.06.14.R  Reported 14-Jun-2017  2017.0  Unprovoked  BAHAMAS
#
#                                  Area Location        Activity  \
# 56                            Unknown      NaN      Snorkeling
# 62                            Unknown      NaN         Surfing
# 101                           Unknown      NaN    Spearfishing
# 110  40 miles off Grand Bahama Island      NaN    Spearfishing
# 132                           Unknown      NaN  Feeding sharks
#
#                     Name Sex Age                           Injury Fatal(Y/N)  \
# 56   Sarah Illig-Carroll   F  25              Minor injury to arm          N
# 62         Timur Yunusov   M  24          Puncture wounds to feet          N
# 101                 male   M  24                     Hand injured          N
# 110       Michael Massey   M  24  Severe lacerations to left hand          N
# 132                Carly   F  24           Fingernail pulled off           N
#
#       Time      Species             InvestigatorOrSource  \
# 56   99h99  Nurse shark           Daily Star, 12/11/2017
# 62   99h99      Unknown                        Instagram
# 101  15h00      Unknown                 CBS12, 8/18/2017
# 110  99h99      Unknown  RevistaJaraysedal.es, 7/26/2017
# 132  99h99      Unknown                AOL.UK, 6/14/2017
#
#                              Pdf  \
# 56        2017.12.09-Carroll.pdf
# 62        2017.11.13.R-Timur.pdf
# 101  2017.08.18-JupiterDiver.pdf
# 110      2017.07.26.R-Massey.pdf
# 132       2017.06.14.R-Carly.pdf
#
#                                            HrefFormula  \
# 56   http://sharkattackfile.net/spreadsheets/pdf_di...
# 62   http://sharkattackfile.net/spreadsheets/pdf_di...
# 101  http://sharkattackfile.net/spreadsheets/pdf_di...
# 110  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# 2008                             South Carolina
# 2017                                    Unknown
# 2027                                    Unknown
# 2044                                    Unknown
# 2140                               North Island
# 2142                                  Saint-Leu
# 2149                            South Australia
# 2160                               Saint-Benoît
# 2196                                    Unknown
# 2208                                  Beaufonds
# 2355                             North Carolina
# 2409                             Tafea Province
# 2440                               Saint-Joseph
# 2469                                     Hawaii
# 2516                                    Florida
# 2551                                 Saint-Paul
# 2706                               Viscayan Sea
# 2758                                    Mindoro
# 2766                 Between DR and Puerto Rico
# 2808                                    Florida
# 2814                              Gulf of Lyons
# 2821                                  Catalonia
# 2869                             Tyrrhenian Sea
# 2882                                    Florida
# 2903                      Eastern Cape Province
# 3033                                    Unknown
# 3038                             Rio de Janeiro
# 3043                             Rio de Janeiro
# 3067                           Romblon Province
# 3098                             North Province
# 3122                           Golfo de Venezia
# 3130                              KwaZulu-Natal
# 3171   South China Sea 200 miles from Hong Kong
# 3205                                 New Jersey
# 3207                                 California
# 3226                                    Florida
# 3237                   Ganges-Brahmaputra delta
# 3318                             Saint-Philippe
# 3329                                 California
# 3345                                    Antibes
# 3387                              Caribbean Sea
# 3393                 200 nm southeast of Manila
# 3409                             Canary Islands
# 3457                                    Florida
# 3472                               Mafia Island
# 3490                                    Florida
# 3491                                    Florida
# 3500                           Rombion Province
# 3508                                    Florida
# 3525                                     Sicily
# 3585                                    Red Sea
# 3588                              North Sumatra
# 3591                                    Unknown
# 3648                      Eastern Cape Province
# 3673                                Connecticut
# 3769                      Eastern Cape Province
# 3774                                  Vita Levu
# 3823                                 California
# 3870                                  Guerrrero
# 3909                       United Arab Emirates
# 3930                               9.35N 79.35W
# 3934                              KwaZulu-Natal
# 3938                                    Unknown
# 3956                                New Britain
# 3957          Enroute from Suez to Aden (Yemen)
# 3967                         Cap-Vert Peninsula
# 3973                                Delagoa Bay
# 4018          Between Timor & Darwin, Australia
# 4062                                     Orissa
# 4121                                     Orissa
# 4187                 1,000 miles east of Hawaii
# 4196                            Yucatan Channel
# 4229                                    Unknown
# 4252                                    Unknown
# 4255                              Torres Strait
# 4256                               Ligurian Sea
# 4323                               Zadar County
# 4373       330 to 350 miles east of Wake Island
# 4432                             South Carolina
# 4445                            Naples Province
# 4454                            Madang Province
# 4470                                      Texas
# 4493                                    Unknown
# 4521                          Western Australia
# 4534  Between Kwajalein Atoll & Johnston Island
# 4550                         Cap Vert Peninsula
# 4560                              KwaZulu-Natal
# 4584                                 Queensland
# 4586                             Rio de Janeiro
# 4621        In transit between Tinian and Leyte
# 4639                                    Unknown
# 4680                                    Unknown
# 4681                                    Unknown
# 4682                            Morobe Province
# 4693                                    Unknown
# 4700                   Off South American coast
# 4702                              04.05N-13.23W
# 4714                West of Ceylon (Sri  Lanka)
# 4731                                    Unknown
# 4735                North of Pernambuco, Brazil
# 4776                               Adriatic Sea
# 4779                      Eastern Cape Province
# 4819                                West Bengal
# 4833                                    Unknown
# 4879                                    Florida
# 4907                    Northern (Oro) Province
# 4923                                  Herzliyah
# 4933                                     Sicily
# 4960                          Western Australia
# 4974                         Northern Territory
    if 'female' in x.lower():
        return  'jane doe'
    if 'girl' in x.lower():
        return  'jane doe'
    if 'sailor' in x.lower():
        return  'john doe'
    if 'men' in x.lower():
        return  'john doe'
    if 'native' in x.lower():
        return 'john doe'
    if 'diver' in x.lower():
        return 'john doe'
    if 'Unidentify' in x:
        return 'unidentify'
    return x

# %%
data1['Name']=data1['Name'].apply(limpiar_name) # APLICAMOS LA FUNCION

# %%
data1.Name.value_counts().head()
# Out:
# john doe        1289
# Unidentified     216
# boat              14
# jane doe          13
# child             12
# Name: Name, dtype: int64

# %% [markdown]
#  NO SABEMOS SI ' A PEARL DRIVER ES H/M ' SOLO POR EL REGISTRO NOMBRE PERO SI LOCALIZAMOS SUS FILAS Y COMPROBAMOS SU SEXO PODEMOS ASIGNARLE AL MENOS 'JOHN O JANE DOE'

# %%
data1[data1.Name.str.contains('a pearl diver')].head() 
data1[data1.Name.str.contains('a native')].head() 
data1[data1.Name.str.contains('a soldier')].head()
# Out:
#         CaseNumber                  Date    Year        Type  Country  \
# 3246  1975.00.00.a                  1975  1975.0  Unprovoked  REUNION
# 4740    1941.08.01           01-Aug-1941  1941.0  Unprovoked      USA
# 4754  1941.00.00.d                  1941  1941.0  Unprovoked     IRAN
# 4948    1934.02.22           22-Feb-1934  1934.0  Unprovoked    CHILE
# 5386  1911.07.31.R  Reported 31-Jul-1911  1911.0  Unprovoked    SPAIN
#
#                     Area                                           Location  \
# 3246             Unknown                                            Unknown
# 4740      South Carolina  Sullivan's Island at entrance to Charleston Ha...
# 4754  Khuzestan Province                          Ahvaz, on the Karun River
# 4948      Elqui Province                                           Coquimbo
# 5386             Málaga                                               Ceuta
#
#                          Activity                           Name Sex Age  \
# 3246                          NaN                      a soldier   M  24
# 4740  Swimming at edge of channel  Howard E. Sweatmon, a soldier   M  20
# 4754                          NaN               a Gurkha soldier   M  24
# 4948          Fell into the water                      a soldier   M  24
# 5386                      Bathing                      a soldier   M  24
#
#                                                  Injury Fatal(Y/N)   Time  \
# 3246                                              FATAL          Y  99h99
# 4740                                    Chest lacerated          N  99h99
# 4754  Survived, but suffered a forequarter amputation          N  99h99
# 4948                                              FATAL          Y  99h99
# 5386                                              FATAL          Y  99h99
#
#       Species                               InvestigatorOrSource  \
# 3246  Unknown                         Reunion Marine Observatory
# 4740  Unknown  V.M. Coppleson (1958), p.153; T. Helm, p.226; ...
# 4754  Unknown                          Lt. Col. R. S. Hunt, p.80
# 4948  Unknown                 Los Angeles Times, 2/23/1934, p.20
# 5386  Unknown                                     C. Moore. GSAF
#
#                                   Pdf  \
# 3246      1975.00.00.a-NV-Reunion.pdf
# 4740          1941.08.01-Sweatmon.pdf
# 4754  1941.00.00.d-Gurkha-soldier.pdf
# 4948     1934.02.22-Soldier-Chile.pdf
# 5386           1911.07.31.R-Ceuta.pdf
#
#                                             HrefFormula  \
# 3246  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4740  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4754  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4948  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5386  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href  CaseNumber.1  \
# 3246  http://sharkattackfile.net/spreadsheets/pdf_di...  1975.00.00.a
# 4740  http://sharkattackfile.net/spreadsheets/pdf_di...    1941.08.01
# 4754  http://sharkattackfile.net/spreadsheets/pdf_di...  1941.00.00.d
# 4948  http://sharkattackfile.net/spreadsheets/pdf_di...    1934.02.22
# 5386  http://sharkattackfile.net/spreadsheets/pdf_di...  1911.07.31.T
#
#       CaseNumber.2  OriginalOrder
# 3246  1975.00.00.a         3057.0
# 4740    1941.08.01         1563.0
# 4754  1941.00.00.d         1549.0
# 4948    1934.02.22         1355.0
# 5386  1911.07.31.R          917.0

# %%
data1['Name'] = data1.Name.str.replace('boat','unknown')
data1['Name'] = data1.Name.str.replace('Anonymous','unknown')
data1['Name'] = data1.Name.str.replace('a pearl diver','john doe')
data1['Name'] = data1.Name.str.replace('a native','john doe')
data1['Name'] = data1.Name.str.replace('a soldier','john doe')
data1['Name'] = data1.Name.str.replace('Unknown','unknown')
data1['Name'] = data1.Name.str.replace('dinghy','unknown')
data1['Name'] = data1.Name.str.replace('M.C.','unknown')
data1['Name'] = data1.Name.str.replace('child','unknown')
data1['Name'] = data1.Name.str.replace('a local dignitary','john doe')
data1['Name'] = data1.Name.str.replace('a youth','john doe')
data1['Name'] = data1.Name.str.replace('a school teacher','john doe')
data1['Name'] = data1.Name.str.replace('Coast Guard personnel','john doe')
data1['Name'] = data1.Name.str.replace('crew','Unidentified')
data1['Name'] = data1.Name.str.replace('unknown','Unidentified')
data1['Name'] = data1.Name.str.replace('teen','Unidentified')
data1['Name'] = data1.Name.str.replace('"john doe"','john doe')
data1['Name'] = data1.Name.str.replace("12' Unidentified",'Unidentified')
data1['Name'] = data1.Name.str.replace('Unidentified x 2','Unidentified')

# %%
data1.Name.value_counts()
# Out:
# john doe                                                                                                                                    1302
# Unidentified                                                                                                                                 273
# jane doe                                                                                                                                      13
# John Williams                                                                                                                                  3
# Davies                                                                                                                                         2
# Charles Cook                                                                                                                                   2
# Michael Massey                                                                                                                                 2
# William Black                                                                                                                                  2
# John Ford                                                                                                                                      2
# a pilot                                                                                                                                        2
# Parang                                                                                                                                         2
# Andy Austin                                                                                                                                    2
# Gary Johnson                                                                                                                                   2
# John Bolling                                                                                                                                   2
# Robert Martin                                                                                                                                  2
# Rafael Hermes Thomas                                                                                                                           2
# Mathew Vickers                                                                                                                                 2
# Rodney Orr                                                                                                                                     2
# Thomas McDonald                                                                                                                                2
# Morris M. Vorenberg                                                                                                                            2
# Hideo Ishida                                                                                                                                   2
# soldier                                                                                                                                        2
# Kenny Burns                                                                                                                                    2
# Hans Hass                                                                                                                                      2
# Gerjo Van Niekerk                                                                                                                              2
# Len Jones                                                                                                                                      2
# Greg Pickering                                                                                                                                 2
# Gordon Harmer                                                                                                                                  2
# Mr. Meyer                                                                                                                                      2
# Theirry Mercredi                                                                                                                               2
# Ken Howell                                                                                                                                     2
# Iona Asai                                                                                                                                      2
# John Hayes                                                                                                                                     2
# Carey Ford                                                                                                                                     2
# Ali                                                                                                                                            2
# Seth Mead                                                                                                                                      2
# Rory OConnor                                                                                                                                  2
# Kazuhiho Kato                                                                                                                                  1
# Robert Sato                                                                                                                                    1
# William Lee Bailey                                                                                                                             1
# 59    31 migrants  NaN  24                                              FATAL
# 86   Unidentified  NaN  24        sharks rammed boats, no injury to occupants
# 124  Unidentified  NaN  24  Skull found in shark, a probable drowning & sc...
# 154  Unidentified  NaN  24                             Minor bite to the foot
#
#     Fatal(Y/N)   Time      Species                    InvestigatorOrSource  \
# 32           N  17h00      Unknown  Les Nouvelles Caledoniennes, 4/10/2018
# 59           Y  99h99   Blue Shark                   TG Com 24, 11/25/2017
# 86           N  99h99  White shark                          B. Myatt, GSAF
# 124        NaN  99h99      Unknown                         Linfo, 7/3/2017
# 154          N  19h00      Unknown   Daytona Beach News-Journal, 4/17/2017
#
#                                Pdf  \
# 32          2018.04.09-Magenta.pdf
# 59          2017.11.25.R-Libya.pdf
# 86   2017.09.14-EsperanceBoats.pdf
# 124         2017.07.02-Comoros.pdf
# 154       2017.04.17.b-Volusia.pdf
#
#                                            HrefFormula  \
# 32   http://sharkattackfile.net/spreadsheets/pdf_di...
# 59   http://sharkattackfile.net/spreadsheets/pdf_di...
# 86   http://sharkattackfile.net/spreadsheets/pdf_di...
# 124  http://sharkattackfile.net/spreadsheets/pdf_di...
# 154  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   Href  CaseNumber.1  \
# 32   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.09
# 59   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.11.25.R
# 86   http://sharkattackfile.net/spreadsheets/pdf_di...    2017.09.14
# 124  http://sharkattackfile.net/spreadsheets/pdf_di...    2017.07.02
# 154  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.04.17.b
#
#      CaseNumber.2  OriginalOrder
# 32     2018.04.09         6271.0
# 59   2017.11.25.R         6244.0
# 86     2017.09.14         6217.0
# 124    2017.07.02         6179.0
# 154  2017.04.17.b         6149.0

# %%
data1.Sex.fillna('Unknown',inplace = True)

# %%
data1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F  57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F  11
# 2                    Habush, Oahu      Surfing      John Denges   M  48
# 3              Arrawarra Headland      Surfing         john doe   M  24
# 4                        La Ticla  Free diving   Gustavo Ramos    M  24
#
#                                               Injury Fatal(Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...          N
# 1                         Minor injury to left thigh          N
# 2       Injury to left lower leg from surfboard skeg          N
# 3                          Minor injury to lower leg          N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT          N
#
#             Time      Species            InvestigatorOrSource  \
# 0          18h00  White shark                R. Collier, GSAF
# 1  14h00  -15h00      Unknown  K.McMurray, TrackingSharks.com
# 2          07h45      Unknown  K.McMurray, TrackingSharks.com
# 3          99h99      Unknown                  B. Myatt, GSAF
# 4          99h99  Tiger shark                       A .Kipper
#
#                         Pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                          HrefFormula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 Href CaseNumber.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   CaseNumber.2  OriginalOrder
# 0   2018.06.25         6303.0
# 1   2018.06.18         6302.0
# 2   2018.06.09         6301.0
# 3   2018.06.08         6300.0
# 4   2018.06.04         6299.0

# %%
data1.Name[data1.Name == 'jane doe' ].index
# Out:
# Int64Index([415, 1508, 1662, 2888, 3607, 4269, 4356, 4393, 4777, 5651, 5667,
#             6245, 6247],
#            dtype='int64')

# %%
johndoesex = data1[(data1.Sex=='Unknown')&(data1.Name=='john doe')]

# %%
johndoesex.head()
# Out:
#          CaseNumber                  Date    Year          Type  \
# 465    2014.12.28.d           28-Dec-2014  2014.0  Sea Disaster
# 1174   2009.01.10.R           10-Jan-2009  2009.0          Boat
# 1637     2004.09.25           25-Sep-2004  2004.0          Boat
# 1743   2003.09.14.b           14-Sep-2003  2003.0          Boat
# 1850  2002.06.13.R1  Reported 13-Jun-2002  2002.0    Unprovoked
#
#                Country                   Area  \
# 465             GREECE                Unknown
# 1174       NEW ZEALAND           North Island
# 1637         AUSTRALIA             Queensland
# 1743      SOUTH AFRICA  Western Cape Province
# 1850  PAPUA NEW GUINEA  Louisiade Archipelago
#
#                                   Location                         Activity  \
# 465   33 nautical miles off Othonoi Island                              NaN
# 1174                            Hawkes Bay                          Fishing
# 1637                             Batt Reef            Spearfishing/ filming
# 1743                         Melkbosstrand                         Fishing
# 1850             Gawa Reefs, Sudest Island  Attempting to retreive a dinghy
#
#           Name      Sex Age  \
# 465   john doe  Unknown  24
# 1174  john doe  Unknown  24
# 1637  john doe  Unknown  24
# 1743  john doe  Unknown  26
# 1850  john doe  Unknown  24
#
#                                                  Injury Fatal(Y/N)   Time  \
# 465    Of 9 bodies recovered, one was bitten by a shark          N  99h99
# 1174  No injury to occupants, shark hit boat & bit o...          N  99h99
# 1637               No injury to occupants, boat damaged          N  12h00
# 1743             No injury to occupants, shark bit boat          N  09h40
# 1850                                              FATAL          Y  99h99
#
#           Species              InvestigatorOrSource  \
# 465       Unknown         Greek Reporter, 1/13/2015
# 1174   Mako Shark     New Zealand Herald, 1/10/2009
# 1637  Tiger shark                  R. Collier, GSAF
# 1743      Unknown                  E. Ritter, GSAF
# 1850      Unknown  PNG Post-Courier, 6/13/2002, p.5
#
#                                    Pdf  \
# 465    2014.12.28.d-NormanAtlantic.pdf
# 1174     2009.01.10.R-Mossman-boat.pdf
# 1637          2004.09.25-CroppBoat.pdf
# 1743         2003.09.14.b-CowShark.pdf
# 1850  2002.06.13.R.1-schoolteacher.pdf
#
#                                             HrefFormula  \
# 465   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1174  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1637  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1743  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1850  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href   CaseNumber.1  \
# 465   http://sharkattackfile.net/spreadsheets/pdf_di...   2014.12.28.d
# 1174  http://sharkattackfile.net/spreadsheets/pdf_di...   2009.01.10.R
# 1637  http://sharkattackfile.net/spreadsheets/pdf_di...     2004.09.25
# 1743  http://sharkattackfile.net/spreadsheets/pdf_di...   2003.09.14.b
# 1850  http://sharkattackfile.net/spreadsheets/pdf_di...  2002.06.13.R1
#
#        CaseNumber.2  OriginalOrder
# 465    2014.12.28.d         5838.0
# 1174   2009.01.10.R         5129.0
# 1637     2004.09.25         4666.0
# 1743   2003.09.14.b         4560.0
# 1850  2002.06.13.R1         4453.0

# %%
johndoesex.Sex.value_counts()
# Out:
# Unknown    54
# Name: Sex, dtype: int64

# %%
data1[(data1.Sex=='unknown')&(data1.Name=='jane doe')]
# Out:
# Empty DataFrame
# Columns: [CaseNumber, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal(Y/N), Time, Species, InvestigatorOrSource, Pdf, HrefFormula, Href, CaseNumber.1, CaseNumber.2, OriginalOrder]
# Index: []

# %%
def limpiar_sex(x):
    
    if data1[(data1.Sex=='Unknown')&(data1.Name=='john doe')].all():
        return 'M'
      
    return x

# %%
data1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F  57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F  11
# 2                    Habush, Oahu      Surfing      John Denges   M  48
# 3              Arrawarra Headland      Surfing         john doe   M  24
# 4                        La Ticla  Free diving   Gustavo Ramos    M  24
#
#                                               Injury Fatal(Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...          N
# 1                         Minor injury to left thigh          N
# 2       Injury to left lower leg from surfboard skeg          N
# 3                          Minor injury to lower leg          N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT          N
#
#             Time      Species            InvestigatorOrSource  \
# 0          18h00  White shark                R. Collier, GSAF
# 1  14h00  -15h00      Unknown  K.McMurray, TrackingSharks.com
# 2          07h45      Unknown  K.McMurray, TrackingSharks.com
# 3          99h99      Unknown                  B. Myatt, GSAF
# 4          99h99  Tiger shark                       A .Kipper
#
#                         Pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                          HrefFormula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 Href CaseNumber.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   CaseNumber.2  OriginalOrder
# 0   2018.06.25         6303.0
# 1   2018.06.18         6302.0
# 2   2018.06.09         6301.0
# 3   2018.06.08         6300.0
# 4   2018.06.04         6299.0

# %%
data1['Sex']=data1['Sex'].apply(limpiar_sex) # APLICAMOS LA FUNCION
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [118], in <cell line: 1>()
# ----> 1 data1['Sex']=data1['Sex'].apply(limpiar_sex)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [116], in limpiar_sex(x)
#       1 def limpiar_sex(x):
# ----> 3     if data1[(data1.Sex=='Unknown')&(data1.Name=='john doe')].all():
#       4         return 'M'
#       6     return x
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### Fatal
#
# Comprobamos que en la columna 'fatal' hay xxx valores nulos
#
# Lineas de codigo basicas de busqueda/modificacion
#
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?
#
# nan_cols = data.isna().sum()
# nan_cols[nan_cols>0]
#
# 2º ¿En que fila estan estos nulos? Contextualizamos con la informacion en el resto de columnas
#
# data[data['nombrecolumna'].isna()]
#
# 3º) SUSTITUIR NULOS por 'Unknown' ceros .... Para poder pasarle la lista de valores a la funcion, nan no interan
#
# data1.nombrecolumna.fillna('Unknown',inplace = True) data1.nombrecolumna.fillna(0,inplace = True)
#
# 4º ¿ QUE VALORES/OBJETOS HAY en esa columna? Buscamos valores nan y/o inconsistente
#
# data.nombrecolumna.unique()
#
# 5º ¿ CUANTOS valores/objetos/elementos hay en esa columna? Buscamos la CANTIDAD de valores inconsistentes
#
# data1.Age.value_counts()

# %%
nan_cols = data1.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Activity                544
# Injury                   28
# Fatal(Y/N)              539
# InvestigatorOrSource     17
# HrefFormula               1
# dtype: int64

# %% [markdown]
# EN UN GOLPE DE VISTA APRECIAMOS QUE LA MAYORIA DE LOS VALORES NULOS EN FATAL(Y/n) ESTAN ASOCIADOS A LA TYPE INVALID

# %%
data1[data1['Fatal(Y/N)'].isna()].head() # DATAFRAME SOLO DE LOS VALORES CON SEX = NAN
# Out:
#       CaseNumber         Date    Year        Type       Country  \
# 27  2018.04.15.c  15-Apr-2018  2018.0  Unprovoked        BRAZIL
# 76    2017.10.01  01-Oct-2017  2017.0     Invalid  SOUTH AFRICA
# 79  2017.09.24.b  24-Sep-2017  2017.0     Invalid           USA
# 84  2017.09.15.b  15-Sep-2017  2017.0     Invalid  SOUTH AFRICA
# 98  2017.08.26.b  26-Aug-2017  2017.0     Invalid         SPAIN
#
#                      Area         Location      Activity            Name Sex  \
# 27             Pernambuco          Piedade      Swimming   Pablo de Melo   M
# 76  Western Cape Province      Dyer Island  Scuba Diving    Bradley Fick   M
# 79               New York         Rockaway       Surfing  Michah Behrend   M
# 84  Western Cape Province          Hawston  Scuba Diving      Wayon Love   M
# 98              Castellón  Grao de Moncofa      Swimming        john doe   F
#
#    Age                                             Injury Fatal(Y/N)   Time  \
# 27  34  Multiple severe injuries to arms and leg, leg ...        NaN  99h99
# 76  31                                              FATAL        NaN  99h99
# 79  33             Lacerations to right ankle, foot & toe        NaN  15h30
# 84  25      FATAL, but death was probably due to drowning        NaN  19h00
# 98  11                           Lacerations to left foot        NaN  12h00
#
#     Species                  InvestigatorOrSource                       Pdf  \
# 27  Unknown                      Globo, 4/16/2018   2018.04.15.c-deMelo.pdf
# 76  Unknown               All Africa, 10/11/2017        2017.10.01-Fick.pdf
# 79  Unknown             S. Curatolo-Wageman, GSAF  2017.09.24.b-Behrend.pdf
# 84  Unknown                  Ground Up, 9/20/2017     2017.09.15.b-Love.pdf
# 98  Unknown  El Periodico Mediterraneo, 8/27/2017    2017.08.26.b-Spain.pdf
#
#                                           HrefFormula  \
# 27  http://sharkattackfile.net/spreadsheets/pdf_di...
# 76  http://sharkattackfile.net/spreadsheets/pdf_di...
# 79  http://sharkattackfile.net/spreadsheets/pdf_di...
# 84  http://sharkattackfile.net/spreadsheets/pdf_di...
# 98  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                  Href  CaseNumber.1  \
# 27  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.c
# 76  http://sharkattackfile.net/spreadsheets/pdf_di...    2017.10.01
# 79  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.24.b
# 84  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.15.b
# 98  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.08.26.b
#
#     CaseNumber.2  OriginalOrder
# 27  2018.04.15.c         6276.0
# 76    2017.10.01         6227.0
# 79  2017.09.24.b         6224.0
# 84  2017.09.15.b         6219.0
# 98  2017.08.26.b         6205.0

# %%
data1['Fatal(Y/N)'].fillna('unknown',inplace = True)

# %%
data1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F  57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F  11
# 2                    Habush, Oahu      Surfing      John Denges   M  48
# 3              Arrawarra Headland      Surfing         john doe   M  24
# 4                        La Ticla  Free diving   Gustavo Ramos    M  24
#
#                                               Injury Fatal(Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...          N
# 1                         Minor injury to left thigh          N
# 2       Injury to left lower leg from surfboard skeg          N
# 3                          Minor injury to lower leg          N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT          N
#
#             Time      Species            InvestigatorOrSource  \
# 0          18h00  White shark                R. Collier, GSAF
# 1  14h00  -15h00      Unknown  K.McMurray, TrackingSharks.com
# 2          07h45      Unknown  K.McMurray, TrackingSharks.com
# 3          99h99      Unknown                  B. Myatt, GSAF
# 4          99h99  Tiger shark                       A .Kipper
#
#                         Pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                          HrefFormula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 Href CaseNumber.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   CaseNumber.2  OriginalOrder
# 0   2018.06.25         6303.0
# 1   2018.06.18         6302.0
# 2   2018.06.09         6301.0
# 3   2018.06.08         6300.0
# 4   2018.06.04         6299.0

# %% [markdown]
# ANALIZAMOS LA RELACION EN FATAL Y TYPE
# DE LOS 539 CASOS NULOS QUE HABIA,EN 524 HAY UNA COINCIDENCIA ENTRE FATAL Y TYPE

# %%
datafatalType = data1[(data1.Type=='Invalid')&(data1['Fatal(Y/N)']== 'unknown')]

# %%
datafatalType.head()
# Out:
#        CaseNumber         Date    Year     Type       Country  \
# 76     2017.10.01  01-Oct-2017  2017.0  Invalid  SOUTH AFRICA
# 79   2017.09.24.b  24-Sep-2017  2017.0  Invalid           USA
# 84   2017.09.15.b  15-Sep-2017  2017.0  Invalid  SOUTH AFRICA
# 98   2017.08.26.b  26-Aug-2017  2017.0  Invalid         SPAIN
# 107  2017.07.29.c  29-Jul-2017  2017.0  Invalid           USA
#
#                       Area                             Location      Activity  \
# 76   Western Cape Province                          Dyer Island  Scuba Diving
# 79                New York                             Rockaway       Surfing
# 84   Western Cape Province                              Hawston  Scuba Diving
# 98               Castellón                      Grao de Moncofa      Swimming
# 107         South Carolina  Hilton Head Island, Beaufort County      Swimming
#
#                    Name Sex Age  \
# 76         Bradley Fick   M  31
# 79       Michah Behrend   M  33
# 84           Wayon Love   M  25
# 98             john doe   F  11
# 107  Johnny Simatacolos   M  10
#
#                                             Injury Fatal(Y/N)   Time  Species  \
# 76                                           FATAL    unknown  99h99  Unknown
# 79          Lacerations to right ankle, foot & toe    unknown  15h30  Unknown
# 84   FATAL, but death was probably due to drowning    unknown  19h00  Unknown
# 98                        Lacerations to left foot    unknown  12h00  Unknown
# 107             Abrasions and cuts to sole of foot    unknown  15h00  Unknown
#
#                      InvestigatorOrSource                           Pdf  \
# 76                All Africa, 10/11/2017            2017.10.01-Fick.pdf
# 79              S. Curatolo-Wageman, GSAF      2017.09.24.b-Behrend.pdf
# 84                   Ground Up, 9/20/2017         2017.09.15.b-Love.pdf
# 98   El Periodico Mediterraneo, 8/27/2017        2017.08.26.b-Spain.pdf
# 107                     C. Creswell, GSAF  2017.07.29.c-Simatacolos.pdf
#
#                                            HrefFormula  \
# 76   http://sharkattackfile.net/spreadsheets/pdf_di...
# 79   http://sharkattackfile.net/spreadsheets/pdf_di...
# 84   http://sharkattackfile.net/spreadsheets/pdf_di...
# 98   http://sharkattackfile.net/spreadsheets/pdf_di...
# 107  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   Href  CaseNumber.1  \
# 76   http://sharkattackfile.net/spreadsheets/pdf_di...    2017.10.01
# 79   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.24.b
# 84   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.15.b
# 98   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.08.26.b
# 107  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.07.29.c
#
#      CaseNumber.2  OriginalOrder
# 76     2017.10.01         6227.0
# 79   2017.09.24.b         6224.0
# 84   2017.09.15.b         6219.0
# 98   2017.08.26.b         6205.0
# 107  2017.07.29.c         6196.0

# %%
datafatalType['Fatal(Y/N)'].value_counts().head()
# Out:
# unknown    524
# Name: Fatal(Y/N), dtype: int64

# %%
data1.shape
# Out:
# (6302, 22)

# %% [markdown]
# ANALIZAMOS LA RELACION EN FATAL Y TYPE
# DE LOS 539 CASOS NULOS QUE HABIA,EN 524 HAY UNA COINCIDENCIA ENTRE FATAL Y TYPE

# %% [markdown]
# Al considerar que los ataques de tipo 'invalid' estan relacionados con el nulo de fatal
# Borramos las filas donde se produzca esta coincidencia

# %%
data1.shape
# Out:
# (6302, 22)

# %% [markdown]
# FILTRAMOS PARA OBTENER AQUELLOS INDICES DE FILA CUYO VALOR COINCIDA TYPE Y FATAL

# %%
bad_index = data1.Type[(data1.Type == 'Invalid') & (data['Fatal(Y/N)']=='unknown')].index

# %%
bad_index
# Out:
# Int64Index([  76,   79,   84,   98,  107,  115,  124,  125,  145,  151,
#             ...
#             6080, 6088, 6108, 6110, 6111, 6126, 6147, 6157, 6164, 6232],
#            dtype='int64', length=524)

# %% [markdown]
# ### BORRAR POR FILAS CONOCIENDO EL INDICE
#
# DATA.DROP(filas(en este caso el indice), inplace = True)

# %%
data1.drop(bad_index, inplace = True)

# %%
data1.shape
# Out:
# (5778, 22)

# %%
dffatalunknown =data1[data1['Fatal(Y/N)']== 'unknown']

# %%
dffatalunknown.head()
# Out:
#         CaseNumber         Date    Year        Type    Country  \
# 27    2018.04.15.c  15-Apr-2018  2018.0  Unprovoked     BRAZIL
# 269   2016.06.02.b  02-Jun-2016  2016.0  Unprovoked  AUSTRALIA
# 294   2016.03.28.b  28-Mar-2016  2016.0  Unprovoked        USA
# 382     2015.07.27  27-Jul-2015  2015.0     Unknown  AUSTRALIA
# 1292    2008.01.30   2008.01.30  2008.0    Provoked      JAPAN
#
#                  Area                      Location      Activity  \
# 27         Pernambuco                       Piedade      Swimming
# 269   New South Wales                    Kingscliff  Spearfishing
# 294           Florida  Fort Myers Beach, Lee County           NaN
# 382          Victoria              Tyrendarra Beach       Surfing
# 1292        Tokyo Bay                       Unknown        Diving
#
#                                   Name Sex Age  \
# 27                       Pablo de Melo   M  34
# 269   Waade Madigan and Dr Seyong Kim    M  24
# 294                          Nick Kawa   M  24
# 382                           john doe   M  40
# 1292                      Unidentified   M  24
#
#                                                  Injury Fatal(Y/N)   Time  \
# 27    Multiple severe injuries to arms and leg, leg ...    unknown  99h99
# 269   No injury, but sharks repeatedly hit their fin...    unknown  99h99
# 294   Minor injury to arm. Possibly caused by smalll...    unknown  99h99
# 382                                      Injury to hand    unknown  99h99
# 1292  No injury, captive shark attempted to bite div...    unknown  99h99
#
#       Species           InvestigatorOrSource                         Pdf  \
# 27    Unknown               Globo, 4/16/2018     2018.04.15.c-deMelo.pdf
# 269   Unknown  Gold Coast Bulletin, 6/4/2016    2016.06.02.b-Matigan.pdf
# 294   Unknown              Fox 35, 3/30/2015       2016.03.28.b-Kawa.pdf
# 382   Unknown                            NaN     2015.07.27-Victoria.pdf
# 1292  Unknown                     L Compagno  2008.01.30-GoblinShark.pdf
#
#                                             HrefFormula  \
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...
# 269   http://sharkattackfile.net/spreadsheets/pdf_di...
# 294   http://sharkattackfile.net/spreadsheets/pdf_di...
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1292  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href  CaseNumber.1  \
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.c
# 269   http://sharkattackfile.net/spreadsheets/pdf_di...  2016.06.02.b
# 294   http://sharkattackfile.net/spreadsheets/pdf_di...  2016.03.28.b
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.07.27
# 1292  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.01.30
#
#       CaseNumber.2  OriginalOrder
# 27    2018.04.15.c         6276.0
# 269   2016.06.02.b         6034.0
# 294   2016.03.28.b         6009.0
# 382     2015.07.27         5921.0
# 1292    2008.01.30         5011.0

# %%
dffatalunknown.index
# Out:
# Int64Index([  27,  269,  294,  382, 1292, 3452, 3506, 4127, 4333, 5630, 5945,
#             6104, 6122, 6125, 6158],
#            dtype='int64')

# %%
data1['Fatal(Y/N)'].unique()
# Out:
# array(['N', 'Y', 'unknown', 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'],
#       dtype=object)

# %%
data1['Fatal(Y/N)'] = data1['Fatal(Y/N)'].str.replace('UNKNOWN','unknown')
data1['Fatal(Y/N)'] = data1['Fatal(Y/N)'].replace(' N','N')
data1['Fatal(Y/N)'] = data1['Fatal(Y/N)'].str.replace('M','N')
data1['Fatal(Y/N)'] = data1['Fatal(Y/N)'].str.replace('2017','unknown')
data1['Fatal(Y/N)'] = data1['Fatal(Y/N)'].str.replace('y','Y')
data1['Fatal(Y/N)'] = data1['Fatal(Y/N)'].str.replace('N ','N')

# %%
data1['Fatal(Y/N)'].value_counts()
# Out:
# N          4302
# Y          1389
# unknown      87
# Name: Fatal(Y/N), dtype: int64

# %% [markdown]
# ### Activity
#
# Comprobamos que en la columna 'activity' hay 544 valores nulos
#
# Lineas de codigo basicas de busqueda/modificacion
#
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?
#
# nan_cols = data.isna().sum()
# nan_cols[nan_cols>0]
#
# 2º ¿En que fila estan estos nulos? Contextualizamos con la informacion en el resto de columnas
#
# data[data['nombrecolumna'].isna()]
#
# 3º) SUSTITUIR NULOS por 'Unknown' ceros .... Para poder pasarle la lista de valores a la funcion, nan no interan
#
# data1.nombrecolumna.fillna('Unknown',inplace = True) data1.nombrecolumna.fillna(0,inplace = True)
#
# 4º ¿ QUE VALORES/OBJETOS HAY en esa columna? Buscamos valores nan y/o inconsistente
#
# data.nombrecolumna.unique()
#
# 5º ¿ CUANTOS valores/objetos/elementos hay en esa columna? Buscamos la CANTIDAD de valores inconsistentes
#
# data1.Age.value_counts()
#
# 6º USO DE FILTROS DE COMPARACIÓN
#
# bad_index = df.nombrecolumna[(df.nombrecolumna == 'condicional') & (df.nombrecolumna=='condicional')].index

# %%
nan_cols = data1.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Activity                423
# Injury                   21
# InvestigatorOrSource     13
# HrefFormula               1
# dtype: int64

# %%
data1[data1.Activity.isna()].head()
# Out:
#        CaseNumber         Date    Year        Type    Country  \
# 47     2018.01.28  28-Jan-2018  2018.0  Unprovoked  AUSTRALIA
# 108  2017.07.29.a  29-Jul-2017  2017.0  Unprovoked        USA
# 112  2017.07.23.b  23-Jul-2017  2017.0  Unprovoked        USA
# 114    2017.07.22  22-Jul-2017  2017.0  Unprovoked        USA
# 154  2017.04.17.b  17-Apr-2017  2017.0  Unprovoked        USA
#
#                   Area                             Location Activity  \
# 47   Western Australia                             Cone Bay      NaN
# 108     South Carolina  DeBordieu Colony, Georgetown County      NaN
# 112         New Jersey                              Ventnor      NaN
# 114            Florida          Snipes Point, Monroe County      NaN
# 154            Florida        Daytona Beach, Volusia County      NaN
#
#                Name      Sex Age                             Injury  \
# 47         john doe        M  18              Injuries to right leg
# 108        john doe        F  12  Bite to left thigh / minor injury
# 112  Isabella Smith        F  24               Minor injury to hand
# 114        john doe        F  40                        Foot bitten
# 154    Unidentified  Unknown  24             Minor bite to the foot
#
#     Fatal(Y/N)   Time      Species                   InvestigatorOrSource  \
# 47           N  08h00   Bull shark                 ABC.net.au, 01/28/2018
# 108          N  19h00      Unknown                      C. Creswell, GSAF
# 112          N  99h99  Tiger shark                               A. Smith
# 114          N  12h30      Unknown                   NBC Miami, 7/23/2017
# 154          N  19h00      Unknown  Daytona Beach News-Journal, 4/17/2017
#
#                              Pdf  \
# 47        2018.01.28-ConeBay.pdf
# 108  2017.07.29.a-Georgetown.pdf
# 112       2017.07.23.b-Smith.pdf
# 114          2017.07.22-Keys.pdf
# 154     2017.04.17.b-Volusia.pdf
#
#                                            HrefFormula  \
# 47   http://sharkattackfile.net/spreadsheets/pdf_di...
# 108  http://sharkattackfile.net/spreadsheets/pdf_di...
# 112  http://sharkattackfile.net/spreadsheets/pdf_di...
# 114  http://sharkattackfile.net/spreadsheets/pdf_di...
# 154  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   Href  CaseNumber.1  \
# 47   http://sharkattackfile.net/spreadsheets/pdf_di...    2018.01.28
# 108  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.07.29.a
# 112  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.07.23.b
# 114  http://sharkattackfile.net/spreadsheets/pdf_di...    2017.07.22
# 154  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.04.17.b
#
#      CaseNumber.2  OriginalOrder
# 47     2018.01.28         6256.0
# 108  2017.07.29.a         6195.0
# 112  2017.07.23.b         6191.0
# 114    2017.07.22         6189.0
# 154  2017.04.17.b         6149.0

# %%
data1.Activity.unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
data1.Activity.value_counts()
# Out:
# Surfing                                                                                                                                                                                                                                                           934
# Swimming                                                                                                                                                                                                                                                          782
# Fishing                                                                                                                                                                                                                                                           413
# Spearfishing                                                                                                                                                                                                                                                      310
# Bathing                                                                                                                                                                                                                                                           150
# Wading                                                                                                                                                                                                                                                            140
# Diving                                                                                                                                                                                                                                                            115
# Standing                                                                                                                                                                                                                                                           98
# Snorkeling                                                                                                                                                                                                                                                         87
# Scuba diving                                                                                                                                                                                                                                                       64
# Body boarding                                                                                                                                                                                                                                                      61
# Body surfing                                                                                                                                                                                                                                                       46
# Swimming                                                                                                                                                                                                                                                           41
# Pearl diving                                                                                                                                                                                                                                                       32
# Kayaking                                                                                                                                                                                                                                                           31
# Treading water                                                                                                                                                                                                                                                     30
# Fell overboard                                                                                                                                                                                                                                                     29
# Free diving                                                                                                                                                                                                                                                        26
# Boogie boarding                                                                                                                                                                                                                                                    25
# Windsurfing                                                                                                                                                                                                                                                        19
# Boogie Boarding                                                                                                                                                                                                                                                    16
# Shark fishing                                                                                                                                                                                                                                                      15
# Walking                                                                                                                                                                                                                                                            15
# Floating                                                                                                                                                                                                                                                           13
# Canoeing                                                                                                                                                                                                                                                           12
# Surf skiing                                                                                                                                                                                                                                                        12
# Fishing                                                                                                                                                                                                                                                            12
# Rowing                                                                                                                                                                                                                                                             12
# Kayak Fishing                                                                                                                                                                                                                                                      11
# Fishing for sharks                                                                                                                                                                                                                                                 11
# Surf-skiing                                                                                                                                                                                                                                                        11
# Surf fishing                                                                                                                                                                                                                                                       10
# Sponge diving                                                                                                                                                                                                                                                      10
# Freediving                                                                                                                                                                                                                                                          9
# Diving for trochus                                                                                                                                                                                                                                                  9
# Sitting on surfboard                                                                                                                                                                                                                                                9
# Fell into the water                                                                                                                                                                                                                                                 9
# Paddle boarding                                                                                                                                                                                                                                                     8
# Free diving for abalone                                                                                                                                                                                                                                             7
# Surfing (sitting on his board)                                                                                                                                                                                                                                      7
# Playing                                                                                                                                                                                                                                                             7
# Sea disaster                                                                                                                                                                                                                                                        7
# Boating                                                                                                                                                                                                                                                             7
# Sailing                                                                                                                                                                                                                                                             7
# Diving for abalone                                                                                                                                                                                                                                                  7
# Spearfishing                                                                                                                                                                                                                                                        7
# Floating on his back                                                                                                                                                                                                                                                7
# Scuba Diving                                                                                                                                                                                                                                                        7
# Skindiving                                                                                                                                                                                                                                                          7
# Surf skiing                                                                                                                                                                                                                                                         6
# Shipwreck                                                                                                                                                                                                                                                           6
# Fishing for mackerel                                                                                                                                                                                                                                                6
# Sea Disaster                                                                                                                                                                                                                                                        6
# Stand-Up Paddleboarding                                                                                                                                                                                                                                             6
# Kite Surfing                                                                                                                                                                                                                                                        6
# Freedom swimming                                                                                                                                                                                                                                                    5
# Surfing                                                                                                                                                                                                                                                             5
# Kite surfing                                                                                                                                                                                                                                                        5
# Kayaking / Fishing                                                                                                                                                                                                                                                  5
# Paddleskiing                                                                                                                                                                                                                                                        5
# Fishing on a boat                                                                                                                                                                                                                                                   5
# Spearfishing on Scuba                                                                                                                                                                                                                                               5
# Boat                                                                                                                                                                                                                                                                5
# Dangling feet in the water                                                                                                                                                                                                                                          5
# Murder                                                                                                                                                                                                                                                              4
# Lifesaving drill                                                                                                                                                                                                                                                    4
# Jumping                                                                                                                                                                                                                                                             4
# Diving for coins                                                                                                                                                                                                                                                    4
# Jumped into the water                                                                                                                                                                                                                                               4
# Body-boarding                                                                                                                                                                                                                                                       4
# Splashing                                                                                                                                                                                                                                                           4
# Boat swamped                                                                                                                                                                                                                                                        4
# Scuba diving (submerged)                                                                                                                                                                                                                                            4
# Scuba diving (but on surface)                                                                                                                                                                                                                                       4
# Paddling on surfboard                                                                                                                                                                                                                                               4
# Tagging sharks                                                                                                                                                                                                                                                      4
# Freedom Swimming                                                                                                                                                                                                                                                    4
# Feeding sharks                                                                                                                                                                                                                                                      4
# Skin diving                                                                                                                                                                                                                                                         4
# Seine netting                                                                                                                                                                                                                                                       4
# Wade Fishing                                                                                                                                                                                                                                                        4
# Hard hat diving                                                                                                                                                                                                                                                     4
# Competing in the Woodvale Atlantic Rowing Race                                                                                                                                                                                                                      3
# Scuba diving for abalone                                                                                                                                                                                                                                            3
# Standing in knee-deep water                                                                                                                                                                                                                                         3
# Fishing for snapper                                                                                                                                                                                                                                                 3
# Walking out of the water after surfing                                                                                                                                                                                                                              3
# Wade fishing                                                                                                                                                                                                                                                        3
# Fishing for kob                                                                                                                                                                                                                                                     3
# Escaping from Alacatraz                                                                                                                                                                                                                                             3
# Shell diving                                                                                                                                                                                                                                                        3
# Spearfishing / free diving                                                                                                                                                                                                                                          3
# Fishing for bluefish                                                                                                                                                                                                                                                3
# Surfing, paddling seawards                                                                                                                                                                                                                                          3
# Swimming after his hat                                                                                                                                                                                                                                              3
# Clamming                                                                                                                                                                                                                                                            3
# Fishing boat                                                                                                                                                                                                                                                        3
# Sculling                                                                                                                                                                                                                                                            3
# Spearing fish                                                                                                                                                                                                                                                       3
# Wreck of the schooner Pohoiki                                                                                                                                                                                                                                       3
# Their 9 m launch was run down by a 25,000-ton Japanese freighter  on the night of 3-11-1977 & they drifted, clinging to an icebox for 2 days                                                                                                                        3
# Spearfishing / Scuba diving (at surface)                                                                                                                                                                                                                            3
# Sitting on gunwale of boat                                                                                                                                                                                                                                          3
# Jumped overboard                                                                                                                                                                                                                                                    3
# Knocked overboard                                                                                                                                                                                                                                                   3
# Wade-fishing                                                                                                                                                                                                                                                        3
# Hookah diving for abalone                                                                                                                                                                                                                                           3
# Playing in the surf                                                                                                                                                                                                                                                 3
# Paddling                                                                                                                                                                                                                                                            3
# Kayak fishing                                                                                                                                                                                                                                                       3
# Shark watching                                                                                                                                                                                                                                                      3
# Diving                                                                                                                                                                                                                                                              3
# Body Boarding                                                                                                                                                                                                                                                       3
# Feeding fish                                                                                                                                                                                                                                                        3
# Fishing for squid                                                                                                                                                                                                                                                   3
# Standing                                                                                                                                                                                                                                                            2
# Kiteboarding                                                                                                                                                                                                                                                        2
# Diving for crayfish                                                                                                                                                                                                                                                 2
# Bathing in river                                                                                                                                                                                                                                                    2
# Diving?                                                                                                                                                                                                                                                             2
# Bathing                                                                                                                                                                                                                                                             2
# Spearfishing Competition                                                                                                                                                                                                                                            2
# Boat with 5 men capsized while returning to the Amerique                                                                                                                                                                                                            2
# Fishing for whiting                                                                                                                                                                                                                                                 2
# Swimming alongside NOAA research vessel Discoverer                                                                                                                                                                                                                  2
# Standing / Surfing                                                                                                                                                                                                                                                  2
# Kitesurfing                                                                                                                                                                                                                                                         2
# Swimming / Wading                                                                                                                                                                                                                                                   2
# Body surfing / treading water                                                                                                                                                                                                                                       2
# Netting shrimp                                                                                                                                                                                                                                                      2
# Spearfishing / Free diving                                                                                                                                                                                                                                          2
# The Christie V sank on 11/6/1988, survivors were adrift on a dinghy                                                                                                                                                                                                 2
# Shark tagging                                                                                                                                                                                                                                                       2
# Spearfishing using Scuba                                                                                                                                                                                                                                            2
# "Flying Tiger" transport plane went down with 5 men onboard                                                                                                                                                                                                         2
# Floating on a raft                                                                                                                                                                                                                                                  2
# Floating on back                                                                                                                                                                                                                                                    2
# Floating in inner tube                                                                                                                                                                                                                                              2
# Hoisting shark aboard fishing boat                                                                                                                                                                                                                                  2
# Diving for trochus shell                                                                                                                                                                                                                                            2
# Scuba diving & spearfishing                                                                                                                                                                                                                                         2
# Fishing from surf ski                                                                                                                                                                                                                                               2
# Sitting in shallows                                                                                                                                                                                                                                                 2
# Hookah diving for sea urchins                                                                                                                                                                                                                                       2
# Free diving, Spearfishing                                                                                                                                                                                                                                           2
# Teasing a shark                                                                                                                                                                                                                                                     2
# Diving for beche-de-mer                                                                                                                                                                                                                                             2
# Dived for a coin                                                                                                                                                                                                                                                    2
# Kayaking                                                                                                                                                                                                                                                            2
# Finning the shark that bit him                                                                                                                                                                                                                                      2
# Diving from canoe                                                                                                                                                                                                                                                   2
# Fishing for lobsters                                                                                                                                                                                                                                                2
# Surfing, collided with shark                                                                                                                                                                                                                                        2
# Fishing for prawns                                                                                                                                                                                                                                                  2
# Diving for beche-de-mer                                                                                                                                                                                                                                             2
# Five men on makeshift raft after their 10 m fishing boat  capsized and sank in rough seas. Survivors rescued after  7.5 hours in the water                                                                                                                          2
# Kite boarding                                                                                                                                                                                                                                                       2
# Free diving & spearfishing                                                                                                                                                                                                                                          2
# Diving for sponges                                                                                                                                                                                                                                                  2
# Diving into water                                                                                                                                                                                                                                                   2
# Washing                                                                                                                                                                                                                                                             2
# Swimming / escaping imprisonment                                                                                                                                                                                                                                    2
# Ocean racing                                                                                                                                                                                                                                                        2
# Swimming near jetty                                                                                                                                                                                                                                                 2
# Spearfishing (free diving)                                                                                                                                                                                                                                          2
# Collecting shells                                                                                                                                                                                                                                                   2
# Launching rowboat through the surf                                                                                                                                                                                                                                  2
# HMAS Parramatta torpedoed & sunk by the U-559                                                                                                                                                                                                                       2
# Swimming, ducking for shells in water 0.9 m deep                                                                                                                                                                                                                    2
# Cruising                                                                                                                                                                                                                                                            2
# U.S. Airforce C124 enroute from Hickham Air Base to Japan went down. The 3 survivors fashioned raft from mailbags  & were rescued 3 days after the crash.                                                                                                           2
# Kite Boarding                                                                                                                                                                                                                                                       2
# Crabbing                                                                                                                                                                                                                                                            2
# Jet skiing                                                                                                                                                                                                                                                          2
# Swimming ashore from capsized boat                                                                                                                                                                                                                                  2
# Fishing for tuna                                                                                                                                                                                                                                                    2
# Beach seine netting                                                                                                                                                                                                                                                 2
# Cleaning fish                                                                                                                                                                                                                                                       2
# Attempting to kill a shark with explosives                                                                                                                                                                                                                          2
# Swimming from the New Venture                                                                                                                                                                                                                                       2
# Crayfishing                                                                                                                                                                                                                                                         2
# Free diving / spearfishing                                                                                                                                                                                                                                          2
# Surfing (lying prone on his board)                                                                                                                                                                                                                                  2
# ...
# Fishing (big game)                                                                                                                                                                                                                                                  1
# Helping men land a shark                                                                                                                                                                                                                                            1
# Free diving for abalone (submerged)                                                                                                                                                                                                                                 1
# Spearfishing, shot a turtle                                                                                                                                                                                                                                         1
# Canoe swamped, swimming back to canoe                                                                                                                                                                                                                               1
# Spearfishing, but standing in the water                                                                                                                                                                                                                             1
# Collecting marine specimens                                                                                                                                                                                                                                         1
# Paddling rescue ski                                                                                                                                                                                                                                                 1
# Walking on reef                                                                                                                                                                                                                                                     1
# %%
data1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F  57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F  11
# 2                    Habush, Oahu      Surfing      John Denges   M  48
# 3              Arrawarra Headland      Surfing         john doe   M  24
# 4                        La Ticla  Free diving   Gustavo Ramos    M  24
#
#                                               Injury Fatal(Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...          N
# 1                         Minor injury to left thigh          N
# 2       Injury to left lower leg from surfboard skeg          N
# 3                          Minor injury to lower leg          N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT          N
#
#             Time      Species            InvestigatorOrSource  \
# 0          18h00  White shark                R. Collier, GSAF
# 1  14h00  -15h00      Unknown  K.McMurray, TrackingSharks.com
# 2          07h45      Unknown  K.McMurray, TrackingSharks.com
# 3          99h99      Unknown                  B. Myatt, GSAF
# 4          99h99  Tiger shark                       A .Kipper
#
#                         Pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                          HrefFormula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 Href CaseNumber.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   CaseNumber.2  OriginalOrder
# 0   2018.06.25         6303.0
# 1   2018.06.18         6302.0
# 2   2018.06.09         6301.0
# 3   2018.06.08         6300.0
# 4   2018.06.04         6299.0

# %%
def limpiar_activity(x):
    
    if 'surfing' in x.lower():
        return 'Surfing'
    if 'swimming' in x.lower():
        return 'Swimming'
    if 'fishing' in x.lower():
        return 'Fishing'
    if 'bathing' in x.lower():
        return 'Bathing'
    if 'blacktip' in x.lower():
        return 'Blacktip Shark'
    if 'wading' in x.lower():
        return 'Wading'
    if 'diving' in x.lower():
        return 'Diving'
    if 'standing' in x.lower():
        return 'Standing'
    if 'snorkeling' in x.lower():
        return 'Snorkeling'
 
    if 'boarding' in x.lower():
        return 'body bording'

    if 'kayak' in x.lower():
        return 'Kayaking'
    if 'canoe' in x.lower():
        return 'canoeing'
    if 'treading' in x.lower():
        return 'Treading water'
    if 'overboard' in x.lower():
        return 'Fell overboard'

    if 'boogie' in x.lower():
        return 'Boogie boarding'
    if 'walking' in x.lower():
        return 'Walking'
    if 'floating' in x.lower():
        return 'Floating'
    if 'skiing' in x.lower():
        return 'Surfing'

    return x

# %%
data1.Activity=data1.Activity.apply(limpiar_activity) # APLICAMOS LA FUNCION

# %%
data1.Activity.value_counts()
# Out:
# Surfing                                                                                                                                                                                                                                                           1125
# Fishing                                                                                                                                                                                                                                                           1093
# Swimming                                                                                                                                                                                                                                                          1008
# Diving                                                                                                                                                                                                                                                             475
# unknown                                                                                                                                                                                                                                                            423
# Bathing                                                                                                                                                                                                                                                            177
# Wading                                                                                                                                                                                                                                                             155
# body bording                                                                                                                                                                                                                                                       139
# Standing                                                                                                                                                                                                                                                           129
# Snorkeling                                                                                                                                                                                                                                                          92
# Fell overboard                                                                                                                                                                                                                                                      80
# Floating                                                                                                                                                                                                                                                            43
# Treading water                                                                                                                                                                                                                                                      36
# Kayaking                                                                                                                                                                                                                                                            34
# canoeing                                                                                                                                                                                                                                                            25
# Walking                                                                                                                                                                                                                                                             20
# Rowing                                                                                                                                                                                                                                                              12
# Sitting on surfboard                                                                                                                                                                                                                                                 9
# Fell into the water                                                                                                                                                                                                                                                  9
# Sailing                                                                                                                                                                                                                                                              7
# Boating                                                                                                                                                                                                                                                              7
# Playing                                                                                                                                                                                                                                                              7
# Sea disaster                                                                                                                                                                                                                                                         7
# Shipwreck                                                                                                                                                                                                                                                            6
# Sea Disaster                                                                                                                                                                                                                                                         6
# Dangling feet in the water                                                                                                                                                                                                                                           5
# Boat                                                                                                                                                                                                                                                                 5
# Murder                                                                                                                                                                                                                                                               4
# Boat swamped                                                                                                                                                                                                                                                         4
# Tagging sharks                                                                                                                                                                                                                                                       4
# Splashing                                                                                                                                                                                                                                                            4
# Jumped into the water                                                                                                                                                                                                                                                4
# Lifesaving drill                                                                                                                                                                                                                                                     4
# Paddling on surfboard                                                                                                                                                                                                                                                4
# Seine netting                                                                                                                                                                                                                                                        4
# Feeding sharks                                                                                                                                                                                                                                                       4
# Jumping                                                                                                                                                                                                                                                              4
# Playing in the surf                                                                                                                                                                                                                                                  3
# Clamming                                                                                                                                                                                                                                                             3
# Competing in the Woodvale Atlantic Rowing Race                                                                                                                                                                                                                       3
# Shark watching                                                                                                                                                                                                                                                       3
# Paddling                                                                                                                                                                                                                                                             3
# Spearing fish                                                                                                                                                                                                                                                        3
# Their 9 m launch was run down by a 25,000-ton Japanese freighter  on the night of 3-11-1977 & they drifted, clinging to an icebox for 2 
colombian  (Avianca) DC-4 airliner plunged into the sea 5 minutes after takeoff                                                                                                                                                                                      1
# wreck of the State Oil Company ship Permina                                                                                                                                                                                                                          1
# Helping men land a shark                                                                                                                                                                                                                                             1
# The World Liberty and the tanker Mosli collided. The  Halcyon Breeze sent a lifeboat to the rescue, but it was smashed, throwing 6 men in the  water.                                                                                                                1
# Overturned skiff                                                                                                                                                                                                                                                     1
# Spent 8 days in dinghy                                                                                                                                                                                                                                               1
# Name: Activity, dtype: int64

# %% [markdown]
# ### injury
#
# Comprobamos que en la columna 'injury' hay 544 valores nulos
#
# Lineas de codigo basicas de busqueda/modificacion
#
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?
#
# nan_cols = data.isna().sum()
# nan_cols[nan_cols>0]
#
# 2º ¿En que fila estan estos nulos? Contextualizamos con la informacion en el resto de columnas
#
# data[data['nombrecolumna'].isna()]
#
# 3º) SUSTITUIR NULOS por 'Unknown' ceros .... Para poder pasarle la lista de valores a la funcion, nan no interan
#
# data1.nombrecolumna.fillna('Unknown',inplace = True) data1.nombrecolumna.fillna(0,inplace = True)
#
# 4º ¿ QUE VALORES/OBJETOS HAY en esa columna? Buscamos valores nan y/o inconsistente
#
# data.nombrecolumna.unique()
#
# 5º ¿ CUANTOS valores/objetos/elementos hay en esa columna? Buscamos la CANTIDAD de valores inconsistentes
#
# data1.Age.value_counts()
#
# 6º USO DE FILTROS DE COMPARACIÓN
#
# bad_index = df.nombrecolumna[(df.nombrecolumna == 'condicional') & (df.nombrecolumna=='condicional')].index

# %%
nan_cols = data1.isna().sum()
nan_cols[nan_cols>0]
# Out:
# Injury                  21
# InvestigatorOrSource    13
# HrefFormula              1
# dtype: int64

# %%
data1[data1.Injury.isna()].head()
# Out:
#         CaseNumber         Date    Year        Type    Country  \
# 1270  2008.04.20.a  20-Apr-2008  2008.0  Unprovoked  AUSTRALIA
# 2250    1997.06.07  07-Jun-1997  1997.0  Unprovoked     BRAZIL
# 2267    1996.12.29  29-Dec-1996  1996.0  Unprovoked  AUSTRALIA
# 2648    1990.00.00         1990  1990.0  Unprovoked        USA
# 3038    1981.03.00     Mar-1981  1981.0  Unprovoked     BRAZIL
#
#                  Area                    Location Activity               Name  \
# 1270  New South Wales               Crescent Head  unknown    Jamie Adlington
# 2250   Rio de Janeiro  Copacabana, Rio de Janeiro  Bathing  José Luiz Lipiani
# 2267       Queensland                Coolum Beach  Surfing         Blair Hall
# 2648          Florida  Pensacola, Escambia County  Surfing           john doe
# 3038   Rio de Janeiro                   Cabo Frio   Diving       Unidentified
#
#           Sex Age Injury Fatal(Y/N)   Time      Species  \
# 1270        M  24    NaN    unknown  99h99  Tiger shark
# 2250        M  24    NaN    unknown  99h99      Unknown
# 2267        M  18    NaN    unknown  18h00      Unknown
# 2648        M  17    NaN    unknown  99h99      Unknown
# 3038  Unknown  24    NaN    unknown  99h99  White shark
#
#                  InvestigatorOrSource                          Pdf  \
# 1270                   T. Peake, GSAF   2008.04.20.a-Adlington.pdf
# 2250                  Globo, 6/9/1997    1997.06.07-NV-Lipiani.pdf
# 2267  The Advertiser, 12/30/1996, p.3     1996.12.29-BlairHall.pdf
# 2648                              NaN  1990.00.00-NV-Pensacola.pdf
# 3038                          Globo,         1981.03.00-Brazil.pdf
#
#                                             HrefFormula  \
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2250  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2267  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2648  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3038  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href  CaseNumber.1  \
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.04.20.a
# 2250  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.06.07
# 2267  http://sharkattackfile.net/spreadsheets/pdf_di...    1996.12.29
# 2648  http://sharkattackfile.net/spreadsheets/pdf_di...    1990.00.00
# 3038  http://sharkattackfile.net/spreadsheets/pdf_di...    1981.03.00
#
#       CaseNumber.2  OriginalOrder
# 1270  2008.04.20.a         5033.0
# 2250    1997.06.07         4053.0
# 2267    1996.12.29         4036.0
# 2648    1990.00.00         3655.0
# 3038    1981.03.00         3265.0

# %%
data1['Injury'].fillna('unknown',inplace = True)

# %%
data1.Injury.unique()
# Out:
# array(['No injury to occupant, outrigger canoe and paddle damaged',
#        'Minor injury to left thigh',
#        'Injury to left lower leg from surfboard skeg', ...,
#        'FATAL, leg stripped of flesh  ',
#        'FATAL, knocked overboard by tail of shark & carried off by shark ',
#        'FATAL. "Shark bit him in half, carrying away the lower extremities" '],
#       dtype=object)

# %%
data1.Injury.value_counts().head()
# Out:
# FATAL          1311
# Survived         94
# Foot bitten      87
# Leg bitten       70
# No injury        60
# Name: Injury, dtype: int64

# %%
def limpiar_injury(x):
    
    if 'fatal' in x.lower():
        return 'FATAL'
    
    return x

# %%
data1.Injury=data1.Injury.apply(limpiar_injury) # APLICAMOS LA FUNCION

# %%
data1.Injury.value_counts().head()
# Out:
# FATAL          1311
# Survived         94
# Foot bitten      87
# Leg bitten       70
# No injury        60
# Name: Injury, dtype: int64

# %% [markdown]
# ### InvestigatorOrSource
#
# Comprobamos que en la columna 'InvestigatorOrSource' hay 21 valores nulos
#
# Lineas de codigo basicas de busqueda/modificacion
#
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?
#
# nan_cols = data.isna().sum()
# nan_cols[nan_cols>0]
#
# 2º ¿En que fila estan estos nulos? Contextualizamos con la informacion en el resto de columnas
#
# data[data['nombrecolumna'].isna()]
#
# 3º) SUSTITUIR NULOS por 'Unknown' ceros .... Para poder pasarle la lista de valores a la funcion, nan no interan
#
# data1.nombrecolumna.fillna('Unknown',inplace = True) data1.nombrecolumna.fillna(0,inplace = True)
#
# 4º ¿ QUE VALORES/OBJETOS HAY en esa columna? Buscamos valores nan y/o inconsistente
#
# data.nombrecolumna.unique()
#
# 5º ¿ CUANTOS valores/objetos/elementos hay en esa columna? Buscamos la CANTIDAD de valores inconsistentes
#
# data1.Age.value_counts()
#
# 6º USO DE FILTROS DE COMPARACIÓN
#
# bad_index = df.nombrecolumna[(df.nombrecolumna == 'condicional') & (df.nombrecolumna=='condicional')].index

# %%
nan_cols = data1.isna().sum()
nan_cols[nan_cols>0]
# Out:
# InvestigatorOrSource    13
# HrefFormula              1
# dtype: int64

# %%
data1[data1.InvestigatorOrSource.isna()].head()
# Out:
#         CaseNumber         Date    Year        Type    Country  \
# 119   2017.07.14.a  14-Jul-2017  2017.0  Unprovoked  AUSTRALIA
# 290   2016.04.07.b  07-Apr-2016  2016.0  Unprovoked        USA
# 382     2015.07.27  27-Jul-2015  2015.0     Unknown  AUSTRALIA
# 631   2013.08.31.b  31-Aug-2013  2013.0  Unprovoked    BAHAMAS
# 1130    2009.04.28  28-Apr-2009  2009.0  Unprovoked        USA
#
#                    Area                          Location Activity  \
# 119   Western Australia                     Floreat Beach  Surfing
# 290             Florida       Florida Keys, Monroe County  Fishing
# 382            Victoria                  Tyrendarra Beach  Surfing
# 631             Unknown                    Freetown Beach  Fishing
# 1130            Florida  St. Augustine, St. John's County  unknown
#
#                  Name Sex Age                                      Injury  \
# 119          john doe   M  24               Minor injury, grazed by shark
# 290   Jonathan Lester   M  34                            Left hand bitten
# 382          john doe   M  40                              Injury to hand
# 631     Bryan Collins   M  24                       Lower left leg bitten
# 1130           Alicia   F  24  Multiple lacerations to right foot & ankle
#
#      Fatal(Y/N)   Time         Species InvestigatorOrSource  \
# 119           N  11h45         Unknown                  NaN
# 290           N  99h99         Unknown                  NaN
# 382     unknown  99h99         Unknown                  NaN
# 631           N  99h99  Blacktip Shark                  NaN
# 1130          N  16h45         Unknown                  NaN
#
#                            Pdf  \
# 119   2017.07.14.a-Floreat.pdf
# 290    2016.04.07.b-Lester.pdf
# 382    2015.07.27-Victoria.pdf
# 631   2013.08.31.b-Collins.pdf
# 1130     2009.04.28-Alicia.pdf
#
#                                             HrefFormula  \
# 119   http://sharkattackfile.net/spreadsheets/pdf_di...
# 290   http://sharkattackfile.net/spreadsheets/pdf_di...
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...
# 631   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1130  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href  CaseNumber.1  \
# 119   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.07.14.a
# 290   http://sharkattackfile.net/spreadsheets/pdf_di...  2016.04.07.b
# 382   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.07.27
# 631   http://sharkattackfile.net/spreadsheets/pdf_di...  2013.08.31.b
# 1130  http://sharkattackfile.net/spreadsheets/pdf_di...    2009.04.28
#
#       CaseNumber.2  OriginalOrder
# 119   2017.07.14.a         6184.0
# 290   2016.04.07.b         6013.0
# 382     2015.07.27         5921.0
# 631   2013.08.31.b         5672.0
# 1130    2009.04.28         5173.0

# %%
data1['InvestigatorOrSource'].fillna('unknown',inplace = True)

# %% [markdown]
# ### HrefFormula
#
# Comprobamos que en la columna 'HrefFormula' hay 1 valores nulos
#
# Lineas de codigo basicas de busqueda/modificacion
#
# 1º ¿ Cuantos nulos hay por columna? ¿Cuantos nulos tengo que modificar?
#
# nan_cols = data.isna().sum()
# nan_cols[nan_cols>0]
#
# 2º ¿En que fila estan estos nulos? Contextualizamos con la informacion en el resto de columnas
#
# data[data['nombrecolumna'].isna()]
#
# 3º) SUSTITUIR NULOS por 'Unknown' ceros .... Para poder pasarle la lista de valores a la funcion, nan no interan
#
# data1.nombrecolumna.fillna('Unknown',inplace = True) data1.nombrecolumna.fillna(0,inplace = True)
#
# 4º ¿ QUE VALORES/OBJETOS HAY en esa columna? Buscamos valores nan y/o inconsistente
#
# data.nombrecolumna.unique()
#
# 5º ¿ CUANTOS valores/objetos/elementos hay en esa columna? Buscamos la CANTIDAD de valores inconsistentes
#
# data1.Age.value_counts()
#
# 6º USO DE FILTROS DE COMPARACIÓN
#
# bad_index = df.nombrecolumna[(df.nombrecolumna == 'condicional') & (df.nombrecolumna=='condicional')].index
#
# 7º USO DE FUNCIONES PARA LIMPIEZA DE DATOS INCONSISTENTES, DEFINIR FUNCIÓN.
#
# 8º REEMPLAZAR DATOS INCONSISTENTES POR AQUELLOS QUE CONSIDEREMOS APROPIEADOS
#
# data.nombrecolumna = data1.nombrecolumna.str.replace('reemplazable','reemplazo')
#
# data1.loc[indice fila ,'nombrecolumna'] = 'nuevo valor'

# %%
nan_cols = data1.isna().sum()
nan_cols[nan_cols>0]
# Out:
# HrefFormula    1
# dtype: int64

# %%
data1[data1.HrefFormula.isna()].head()
# Out:
#       CaseNumber         Date    Year        Type    Country             Area  \
# 3244  1975.01.19  19-Jan-1975  1975.0  Unprovoked  AUSTRALIA  South Australia
#
#         Location Activity      Name Sex Age Injury Fatal(Y/N)   Time  Species  \
# 3244  Coffin Bay  Surfing  john doe   M  17  FATAL          Y  99h99  Unknown
#
#                                    InvestigatorOrSource  \
# 3244  J. West; Adelaide Advertiser, 1/20/1975; P. Ke...
#
#                            Pdf HrefFormula  \
# 3244  1975.01.19-Barrowman.pdf         NaN
#
#                                                    Href CaseNumber.1  \
# 3244  http://sharkattackfile.net/spreadsheets/pdf_di...   1975.01.19
#
#      CaseNumber.2  OriginalOrder
# 3244   1975.01.19         3059.0

# %%
data1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location  Activity             Name Sex Age  \
# 0     Oceanside, San Diego County  Paddling      Julie Wolfe   F  57
# 1  St. Simon Island, Glynn County  Standing  Adyson McNeely    F  11
# 2                    Habush, Oahu   Surfing      John Denges   M  48
# 3              Arrawarra Headland   Surfing         john doe   M  24
# 4                        La Ticla    Diving   Gustavo Ramos    M  24
#
#                                               Injury Fatal(Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...          N
# 1                         Minor injury to left thigh          N
# 2       Injury to left lower leg from surfboard skeg          N
# 3                          Minor injury to lower leg          N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT          N
#
#             Time      Species            InvestigatorOrSource  \
# 0          18h00  White shark                R. Collier, GSAF
# 1  14h00  -15h00      Unknown  K.McMurray, TrackingSharks.com
# 2          07h45      Unknown  K.McMurray, TrackingSharks.com
# 3          99h99      Unknown                  B. Myatt, GSAF
# 4          99h99  Tiger shark                       A .Kipper
#
#                         Pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                          HrefFormula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 Href CaseNumber.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.04
#
#   CaseNumber.2  OriginalOrder
# 0   2018.06.25         6303.0
# 1   2018.06.18         6302.0
# 2   2018.06.09         6301.0
# 3   2018.06.08         6300.0
# 4   2018.06.04         6299.0

# %%
data1.loc[3244,'HrefFormula'] = 'http://sharkattackfile.net/spreadsheets/pdf_di...	'
